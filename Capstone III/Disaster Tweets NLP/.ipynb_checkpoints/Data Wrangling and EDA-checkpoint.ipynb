# %% [markdown]
# # Disaster Tweet Detector (NLP): Data Wrangling and EDA

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
from cleantext import clean
from nltk.tokenize import TweetTokenizer
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
from gensim.models.tfidfmodel import TfidfModel
from gensim.corpora.dictionary import Dictionary

# %% [markdown]
# ## Importing Data

# %%
tweets = pd.read_csv('C:/Users/justi/SpringboardDS/Capstone III/data/tweets.csv')
tweets.head()
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0

# %% [markdown]
# ## Exploring the Data

# %%
# Create countplot to check for balanced/unbalanced data.
sns.countplot(tweets['target'])
# Out:
# C:\Users\justi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='target', ylabel='count'>

# %%
# Get frequency counts of target.
tweets['target'].value_counts()
# Out:
# 0    9256
# 1    2114
# Name: target, dtype: int64

# %%
# Get frequency percents of target.
tweets['target'].value_counts(normalize=True)
# Out:
# 0    0.814072
# 1    0.185928
# Name: target, dtype: float64

# %%
# Check variable types.
tweets.dtypes
# Out:
# id           int64
# keyword     object
# location    object
# text        object
# target       int64
# dtype: object

# %% [markdown]
# ## Text Cleaning and Tokenization

# %%
# Eliminate unwanted characters using regular expressions and stop words/non alpha characters
# Retrieve tokens of all words in tweets (use twittertokenization for hashtags and stuff) --> will be list of lists with each one being a tweet
# Lemmatize the tokens/words
# Create a corpus using dictionary.doc2bow(tweets)
# Plot tweet word counts by counting tokens in tweets
# Make tokens lower case and use Counter() to count the most common word occurance throughout the corupus (all tweets)

# %%
# running into issues with the html - not sure how to decode and make it work
def clean_text(text):
    # remove numbers
    text_nonum = re.sub(r'\d+', '', text)
    # remove punctuations and convert characters to lower case
    text_nopunct = "".join([char.lower() for char in text_nonum if char not in string.punctuation]) 
    # substitute multiple whitespace with single whitespace
    # also, removes leading and trailing whitespaces
    text_no_doublespace = re.sub('\s+', ' ', text_nopunct).strip()
    text_no_links = re.sub(r' http\S+', '', text_no_doublespace) # remove words starting with https to get rid of links (also the space in front of the link)
    text_no_emotes = clean(text_no_links, no_emoji=True) # remove emotes along with other cleantext operations
    return text_no_emotes

# %%
# Create a list of tweets to work with until later converting it back to a dataframe column.
tweets_list = tweets.text

# Iterate throguh all tweets. Append tweets to an empty list.
mylist=[]

for i in tweets_list[:11371]:
    cleaned_tweet = clean_text(i)
    mylist.append(cleaned_tweet)

# %%
# Check to see if all tweets were appended.
len(mylist)
# Out:
# 11370

# %%
# Inspect first few tweets.
mylist[:10]
# Out:
# ['communal violence in bhainsa telangana stones were pelted on muslims houses and some houses and vehicles were set ablaze...',
#  'telangana section has been imposed in bhainsa from january to after clash erupted between two groups on january po...',
#  'arsonist sets cars ablaze at dealership',
#  'arsonist sets cars ablaze at dealership',
#  'lord jesus your love brings freedom and pardon fill me with your holy spirit and set my heart ablaze with your l...',
#  'if this child was chinese this tweet would have gone viral social media would be ablaze snl would have made a racist j...',
#  'several houses have been set ablaze in ngemsibaa village oku sub division in the north west region of cameroon by...',
#  'asansol a bjp office in salanpur village was set ablaze last night bjp has alleged that tmc is behind the incident police has b...',
#  'national security minister kan dapaahs side chic has set the internet ablaze with her latest powerful video...',
#  "this creature who's soul is no longer clarent but blue ablaze this thing carrying memories memories of..."]

# %%
# Might have to also deal with other languages (saw some chinese in first 1000 tweets)

# %%
# Initiate TweetTokenizer and apply it to our text column.
tt = TweetTokenizer()

mylist_tokenized=[]

for i in mylist:
    token = tt.tokenize(i)
    mylist_tokenized.append(token)

# %%
# Check to see if our new list is formatted correctly.
mylist_tokenized
# Out:
# [['communal',
#   'violence',
#   'in',
#   'bhainsa',
#   'telangana',
#   'stones',
#   'were',
#   'pelted',
#   'on',
#   'muslims',
#   'houses',
#   'and',
#   'some',
#   'houses',
#   'and',
#   'vehicles',
#   'were',
#   'set',
#   'ablaze',
#   '...'],
#  ['telangana',
#   'section',
#   'has',
#   'been',
#   'imposed',
#   'in',
#   'bhainsa',
#   'from',
#   'january',
#   'to',
#   'after',
#   'clash',
#   'erupted',
#   'between',
#   'two',
#   'groups',
#   'on',
#   'january',
#   'po',
#   '...'],
#  ['arsonist', 'sets', 'cars', 'ablaze', 'at', 'dealership'],
#  ['arsonist', 'sets', 'cars', 'ablaze', 'at', 'dealership'],
#  ['lord',
#   'jesus',
#   'your',
#   'love',
#   'brings',
#   'freedom',
#   'and',
#   'pardon',
#   'fill',
#   'me',
#   'with',
#   'your',
#   'holy',
#   'spirit',
#   'and',
#   'set',
#   'my',
#   'heart',
#   'ablaze',
#   'with',
#   'your',
#   'l',
#   '...'],
#  ['if',
#   'this',
#   'child',
#   'was',
#   'chinese',
#   'this',
#   'tweet',
#   'would',
#   'have',
#   'gone',
#   'viral',
#   'social',
#   'media',
#   'would',
#   'be',
#   'ablaze',
#   'snl',
#   'would',
#   'have',
#   'made',
#   'a',
#   'racist',
#   'j',
#   '...'],
#  ['several',
#   'houses',
#   'have',
#   'been',
#   'set',
#   'ablaze',
#   'in',
#   'ngemsibaa',
#   'village',
#   'oku',
#   'sub',
#   'division',
#   'in',
#   'the',
#   'north',
#   'west',
#   'region',
#   'of',
#   'cameroon',
#   'by',
#   '...'],
#  ['asansol',
#   'a',
#   'bjp',
#   'office',
#   'in',
#   'salanpur',
#   'village',
#   'was',
#   'set',
#   'ablaze',
#   'last',
#   'night',
#   'bjp',
#   'has',
#   'alleged',
#   'that',
#   'tmc',
#   'is',
#   'behind',
#   'the',
#   'incident',
#   'police',
#   'has',
#   'b',
#   '...'],
#  ['national',
#   'security',
#   'minister',
#   'kan',
#   'dapaahs',
#   'side',
#   'chic',
#   'has',
#   'set',
#   'the',
#   'internet',
#   'ablaze',
#   'with',
#   'her',
#   'latest',
#   'powerful',
#   'video',
#   '...'],
#  ['this',
#   'creature',
#   "who's",
#   'soul',
#   'is',
#   'no',
#   'longer',
#   'clarent',
#   'but',
#   'blue',
#   'ablaze',
#   'this',
#   'thing',
#   'carrying',
#   'memories',
#   'memories',
#   'of',
#   '...'],
#  ['images',
#   'showing',
#   'the',
#   'havoc',
#   'caused',
#   'by',
#   'the',
#   'cameroon',
#   'military',
#   'as',
#   'they',
#   'torched',
#   'houses',
#   'in',
#   'okuthe',
#   'shameless',
#   'military',
#   'is',
#   'reported',
#   '...'],
#  ['social',
#   'media',
#   'went',
#   'bananas',
#   'after',
#   'chuba',
#   'hubbard',
#   'announced',
#   'monday',
#   'evening',
#   'his',
#   'plans',
#   'to',
#   'return',
#   'to',
#   'okstate'],
#  ['hausa',
#   'youths',
#   'set',
#   'area',
#   'office',
#   'of',
#   'apapaiganmu',
#   'local',
#   'council',
#   'development',
#   'area',
#   'ablaze',
#   'okada',
#   'riders',
#   'stormed',
#   'the',
#   'lg',
#   'area',
#   'office',
#   '...'],
#  ['under',
#   'mamatabanerjee',
#   'political',
#   'violence',
#   'amp',
#   'vandalism',
#   'continues',
#   'to',
#   'unabated',
#   'in',
#   'west',
#   'bengal',
#   'office',
#   'in',
#   'asanol',
#   'was',
#   '...'],
#  ['amen', 'set', 'the', 'whole', 'system', 'ablaze', 'man'],
#  ['images',
#   'showing',
#   'the',
#   'havoc',
#   'caused',
#   'by',
#   'the',
#   'cameroon',
#   'military',
#   'as',
#   'they',
#   'torched',
#   'houses',
#   'in',
#   'okuthe',
#   'shameless',
#   'military',
#   'is',
#   '...'],
#  ['no',
#   'cows',
#   'today',
#   'but',
#   'our',
#   'local',
#   'factory',
#   'is',
#   'sadly',
#   'still',
#   'ablaze',
#   'redjanuary'],
#  ['rengoku',
#   'sets',
#   'my',
#   'heart',
#   'ablaze',
#   'ps',
#   'i',
#   'missed',
#   'this',
#   'style',
#   'of',
#   'coloring',
#   'i',
#   'do',
#   'so',
#   'here',
#   'it',
#   'is',
#   'c',
#   'gui',
#   'mie',
#   'noren'],
#  ['paulzizkaphoto',
#   '"',
#   'rundle',
#   'ablaze',
#   '"',
#   'wishing',
#   'you',
#   'all',
#   'a',
#   'good',
#   'evening'],
#  ['french',
#   'cameroun',
#   'set',
#   'houses',
#   'ablaze',
#   'in',
#   'ndu',
#   'and',
#   'roasted',
#   'two',
#   'young',
#   'boys',
#   'in',
#   'their',
#   'homes',
#   'in',
#   'targeted',
#   'killings',
#   'in',
#   'a',
#   'genocideinsou',
#   '...'],
#  ['cameroons',
#   'bir',
#   'soldiers',
#   'on',
#   'the',
#   'invaded',
#   'the',
#   'southerncameroons',
#   'village',
#   'of',
#   'kimar',
#   'so',
#   'setting',
#   'ablaze',
#   'a',
#   'total',
#   'of',
#   '...'],
#  ['as',
#   'fires',
#   'ablaze',
#   'throughout',
#   'the',
#   'landas',
#   'the',
#   'prophosized',
#   'apocalypse',
#   'comes',
#   'to',
#   'fruitionnot',
#   'a',
#   'building',
#   'standingas',
#   'we',
#   'all',
#   'come',
#   'st',
#   '...'],
#  ['thankfultuesday',
#   'isaiah',
#   'when',
#   'you',
#   'pass',
#   'through',
#   'the',
#   'waters',
#   'i',
#   'will',
#   'be',
#   'with',
#   'you',
#   'and',
#   'when',
#   'you',
#   'pass',
#   'through',
#   'the',
#   'r',
#   '...'],
#  ['when',
#   'you',
#   'walk',
#   'through',
#   'the',
#   'fire',
#   'you',
#   'will',
#   'not',
#   'be',
#   'scorched',
#   'and',
#   'the',
#   'flames',
#   'will',
#   'not',
#   'set',
#   'you',
#   'ablaze',
#   '-',
#   '-',
#   '-',
#   'product',
#   '...'],
#  ['originally',
#   'they',
#   'were',
#   'intended',
#   'to',
#   'be',
#   'fired',
#   'at',
#   'boarders',
#   'or',
#   'the',
#   'opposing',
#   'ships',
#   'crew',
#   'from',
#   'gunners',
#   'in',
#   'the',
#   'shipss',
#   'riggi',
#   '...'],
#  ['warm',
#   'greetings',
#   'to',
#   'all',
#   'on',
#   'the',
#   'occasion',
#   'of',
#   'lohri',
#   'as',
#   'winter',
#   'passes',
#   'by',
#   'may',
#   'everyones',
#   'woes',
#   'and',
#   'troubles',
#   'be',
#   'set',
#   'ablaze',
#   'in',
#   't',
#   '...'],
#  ['another',
#   'arson',
#   'in',
#   'njikomboyonwr',
#   'the',
#   'ambazombies',
#   'yesterday',
#   'set',
#   'ablaze',
#   'the',
#   'council',
#   'building',
#   'which',
#   'country',
#   'in',
#   'the',
#   'wo',
#   '...'],
#  ['another',
#   'public',
#   'market',
#   'in',
#   'haiti',
#   'mysteriously',
#   'set',
#   'ablaze',
#   'the',
#   'independent',
#   'merchants',
#   'who',
#   'are',
#   'overwhelmingly',
#   'women',
#   'become',
#   '...'],
#  ['that', 'is', 'kind', 'true', 'sadly'],
#  ['i', 'swear', 'that', 'jam', 'will', 'set', 'the', 'world', 'ablaze'],
#  ['marivan',
#   'kurdistan',
#   'province',
#   'monday',
#   'jan',
#   'th',
#   'protesters',
#   'set',
#   'the',
#   'propaganda',
#   'banner',
#   'of',
#   'qassemsoleimani',
#   'ablaze',
#   'i',
#   '...'],
#  ['marivan',
#   'kurdistan',
#   'province',
#   'monday',
#   'jan',
#   'th',
#   'protesters',
#   'set',
#   'the',
#   'propaganda',
#   'banner',
#   'of',
#   'qassemsoleimani',
#   'ablaze',
#   '...'],
#  ['how',
#   'can',
#   'you',
#   'turn',
#   'a',
#   'blind',
#   'eye',
#   'to',
#   'the',
#   'icident',
#   'of',
#   'setting',
#   'ablaze',
#   'more',
#   'than',
#   'houses',
#   'of',
#   'h',
#   '...'],
#  ['this',
#   'love',
#   'is',
#   'so',
#   'completely',
#   'crazy',
#   'youve',
#   'been',
#   'fucking',
#   'with',
#   'my',
#   'dreams',
#   'ripped',
#   'me',
#   'like',
#   'your',
#   'torn',
#   'up',
#   'jeans',
#   'i',
#   'dont',
#   'ev',
#   '...'],
#  ['terms',
#   'in',
#   'a',
#   'demon',
#   'burning',
#   'dark',
#   'the',
#   'ruined',
#   'people',
#   'who',
#   'cannot',
#   'use',
#   'magic',
#   'or',
#   'interact',
#   'with',
#   'it',
#   'without',
#   'some',
#   'harm',
#   'or',
#   'ac',
#   '...'],
#  ['heartfelt',
#   'appreciation',
#   'to',
#   'prime',
#   'minister',
#   'yab',
#   'tun',
#   'dr',
#   'wife',
#   'yabhg',
#   'tun',
#   'dr',
#   'siti',
#   'hasmah',
#   'mohd',
#   'ali',
#   'fo',
#   '...'],
#  ['watch',
#   'former',
#   'cm',
#   'akhilesh',
#   'yadav',
#   'who',
#   'went',
#   'to',
#   'meet',
#   'injured',
#   'of',
#   'kannauj',
#   'accident',
#   'at',
#   'a',
#   'hospital',
#   'in',
#   'chhibramau',
#   'asks',
#   'emergency',
#   'med',
#   '...'],
#  ['he',
#   'gave',
#   'us',
#   'everything',
#   'he',
#   'had',
#   'a',
#   'horrible',
#   'foot',
#   'infection',
#   'once',
#   'so',
#   'wore',
#   'one',
#   'thong',
#   '...'],
#  ['yeah',
#   'his',
#   'new',
#   'swag',
#   'is',
#   'on',
#   'point',
#   'since',
#   'the',
#   'accident',
#   'like',
#   'this',
#   'is',
#   'a',
#   'totally',
#   'transformed',
#   'bob',
#   '...'],
#  ['this',
#   'is',
#   'cool',
#   'and',
#   'all',
#   'these',
#   'days',
#   'i',
#   'have',
#   'been',
#   'doing',
#   'git',
#   'push',
#   'origin',
#   'currentbranchname',
#   'you',
#   'know',
#   'that',
#   '...'],
#  ['preorder',
#   'newrelease',
#   'today',
#   'witnesses',
#   'connected',
#   'to',
#   'or',
#   'investigating',
#   'thenutcrackerconspiracy',
#   'have',
#   'died',
#   'either',
#   'in',
#   'a',
#   '...'],
#  ['my',
#   'back',
#   'and',
#   'neck',
#   'are',
#   'still',
#   'fucked',
#   'up',
#   'from',
#   'the',
#   'accident'],
#  ['rt',
#   'prince',
#   'harry',
#   'just',
#   'confirmed',
#   'that',
#   'his',
#   "mother's",
#   'princess',
#   'diana',
#   'death',
#   'was',
#   'not',
#   'an',
#   'accident'],
#  ['note',
#   'to',
#   'democrats',
#   "it's",
#   'not',
#   'a',
#   'muslim',
#   'ban',
#   'islam',
#   'is',
#   'not',
#   'a',
#   'race',
#   'soleimani',
#   'was',
#   'a',
#   'terrorist',
#   'amp',
#   'was',
#   'exterminated',
#   'not',
#   'assas',
#   '...'],
#  ['juwan',
#   'johnsonoregon',
#   'is',
#   'one',
#   'big',
#   'dude',
#   'looks',
#   'like',
#   'a',
#   'tight',
#   'end',
#   'stuck',
#   'in',
#   'the',
#   'receiver',
#   'group',
#   'by',
#   'accident'],
#  ['more',
#   'appearances',
#   'of',
#   'the',
#   'man',
#   'with',
#   'the',
#   'upsidedown',
#   'face',
#   'a',
#   'new',
#   "year's",
#   'eve',
#   'party',
#   'at',
#   'an',
#   'air',
#   'force',
#   'base',
#   'in',
#   'where',
#   'a',
#   'man',
#   '...'],
#  ['the',
#   'speeding',
#   'car',
#   'rammed',
#   'into',
#   'a',
#   'group',
#   'of',
#   'people',
#   'who',
#   'were',
#   'returning',
#   'after',
#   'attending',
#   'a',
#   'temple',
#   'festival',
#   'of',
#   'ayyappan',
#   'kavu',
#   'in',
#   'thum',
#   '...'],
#  ['my',
#   'friend',
#   'an',
#   'army',
#   'just',
#   'lost',
#   'her',
#   'father',
#   'in',
#   'an',
#   'accident',
#   'and',
#   'her',
#   'mom',
#   'right',
#   'now',
#   'is',
#   'still',
#   'unconscious',
#   'please',
#   'pray',
#   'for',
#   'her',
#   'mo',
#   '...'],
#  ['mlindo', 'the', 'vocalist', 'in', 'another', 'car', 'accident'],
#  ['"',
#   'there',
#   'are',
#   'no',
#   'greater',
#   'treasures',
#   'than',
#   'the',
#   'highest',
#   'human',
#   'qualities',
#   'such',
#   'as',
#   'compassion',
#   'courage',
#   'and',
#   'hope',
#   'not',
#   'even',
#   'tragic',
#   'accide',
#   '...'],
#  ['please',
#   'help',
#   'our',
#   'friends',
#   'in',
#   'they',
#   'have',
#   'had',
#   'a',
#   'non',
#   'fault',
#   'accident',
#   'thats',
#   'resulted',
#   'in',
#   'their',
#   'vehicle',
#   'being',
#   'writte',
#   '...'],
#  ['when',
#   'you',
#   'hurt',
#   'your',
#   'younger',
#   'sibling',
#   'by',
#   '"',
#   'accident',
#   '"'],
#  ['david',
#   "cameron's",
#   'decision',
#   'to',
#   'hold',
#   'a',
#   'referendum',
#   'expressed',
#   'in',
#   'the',
#   'medium',
#   'of',
#   'a',
#   'road',
#   'traffic',
#   'accident'],
#  ['an',
#   'auto',
#   'accident',
#   'injury',
#   'can',
#   'set',
#   'a',
#   'process',
#   'in',
#   'motion',
#   'that',
#   'can',
#   'get',
#   'complicated',
#   'find',
#   'out',
#   'how',
#   'long',
#   'it',
#   'takes',
#   'to',
#   'settle',
#   '...'],
#  ['no',
#   'one',
#   'has',
#   'the',
#   'right',
#   'to',
#   'call',
#   'a',
#   'baby',
#   'an',
#   'accident',
#   'jd',
#   'himself',
#   'called',
#   'it',
#   'a',
#   'blessing',
#   'he',
#   'used',
#   'the',
#   'loveliest',
#   'word',
#   'to',
#   'describe',
#   'what',
#   '...'],
#  ['i',
#   'actually',
#   'posted',
#   'this',
#   'by',
#   'accident',
#   'to',
#   'twitter',
#   'but',
#   'have',
#   'decided',
#   'this',
#   'can',
#   'stay'],
#  ['question',
#   "let's",
#   'say',
#   'you',
#   'are',
#   'happily',
#   'married',
#   'and',
#   'your',
#   'husband',
#   'dies',
#   'in',
#   'a',
#   'tragic',
#   'accident',
#   'you',
#   'are',
#   'deveststed',
#   'but',
#   'this',
#   'pussy',
#   'not',
#   '...'],
#  ['the',
#   'kampala',
#   'metropolitan',
#   'east',
#   'has',
#   'in',
#   'custody',
#   'two',
#   'suspects',
#   'who',
#   'allegedly',
#   'strangled',
#   'to',
#   'death',
#   'a',
#   'passenger',
#   '...'],
#  ['in',
#   'completely',
#   'available',
#   'public',
#   'information',
#   'the',
#   'fires',
#   'were',
#   'mostly',
#   'started',
#   'by',
#   'humans',
#   'on',
#   'purpose',
#   'or',
#   'on',
#   'accident',
#   'with',
#   'th',
#   '...'],
#  ['during',
#   'my',
#   'phd',
#   'there',
#   'was',
#   'a',
#   'colleague',
#   'who',
#   'went',
#   'out',
#   'of',
#   'her',
#   'way',
#   'to',
#   'bully',
#   'and',
#   'cause',
#   'work',
#   'discomfort',
#   'for',
#   'me',
#   'i',
#   '...'],
#  ['the',
#   'speeding',
#   'car',
#   'rammed',
#   'into',
#   'a',
#   'group',
#   'of',
#   'people',
#   'who',
#   'were',
#   'returning',
#   'after',
#   'attending',
#   'a',
#   'temple',
#   'festival',
#   'of',
#   'ayyappan',
#   'ka',
#   '...'],
#  ['yr',
#   'old',
#   'bella',
#   'needs',
#   'a',
#   'new',
#   'home',
#   'due',
#   'to',
#   'an',
#   'incident',
#   'that',
#   'was',
#   'an',
#   'accident',
#   'she',
#   'can',
#   'live',
#   'with',
#   'older',
#   'kids',
#   'and',
#   'in',
#   'the',
#   'right',
#   'ho',
#   '...'],
#  ['look',
#   'at',
#   'this',
#   'shitshe',
#   'need',
#   'her',
#   'little',
#   'ass',
#   'whooped',
#   'before',
#   'she',
#   'hit',
#   'somebody',
#   'by',
#   'accident',
#   'lecheminduroi',
#   'bransoncognac',
#   'starzge',
#   '...'],
#  ['youre',
#   'not',
#   'an',
#   'accident',
#   'on',
#   'the',
#   'earth',
#   'youre',
#   'gods',
#   'divinely',
#   'crafted',
#   'masterpiece',
#   'he',
#   'designed',
#   'you',
#   'with',
#   'a',
#   'destiny',
#   'in',
#   'v',
#   '...'],
#  ['iran',
#   'says',
#   'that',
#   'they',
#   'shot',
#   'down',
#   'ukraine',
#   'international',
#   'flight',
#   'by',
#   'accident',
#   'here',
#   'is',
#   'an',
#   'picture',
#   'of',
#   'that',
#   'aircraft',
#   'in',
#   '...'],
#  ['saw',
#   'this',
#   'truck',
#   'with',
#   'the',
#   'container',
#   'almost',
#   'falling',
#   'off',
#   'this',
#   'morning',
#   'reported',
#   '...'],
#  ['judge',
#   'less',
#   'smile',
#   'more',
#   'it',
#   "isn't",
#   'the',
#   'oldest',
#   'profession',
#   'by',
#   'accident',
#   'lol'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['aftershock',
#   'at',
#   'am',
#   'i',
#   'was',
#   'asleep',
#   'and',
#   'the',
#   'movement',
#   'of',
#   'my',
#   'bed',
#   'woke',
#   'me',
#   'up',
#   'not',
#   'so',
#   'scary',
#   'but',
#   'i',
#   'wish',
#   'they',
#   'werent',
#   '...'],
#  ['good',
#   'night',
#   'my',
#   'friends',
#   'as',
#   'per',
#   'usgs',
#   'the',
#   'new',
#   'quake',
#   'in',
#   'this',
#   'morning',
#   'caused',
#   'the',
#   'day',
#   'aftershock',
#   'forecast',
#   'to',
#   'change',
#   '...'],
#  ['yea',
#   'it',
#   'wasnt',
#   'that',
#   'long',
#   'she',
#   'killed',
#   'me',
#   'in',
#   'like',
#   'or',
#   'seconds',
#   'but',
#   'not',
#   'sure',
#   'would',
#   'have',
#   'to',
#   '...'],
#  ['honored',
#   'to',
#   'have',
#   'an',
#   'essay',
#   'in',
#   'aftershock',
#   'marking',
#   'the',
#   'th',
#   'anniversary',
#   'of',
#   'alvin',
#   "toffler's",
#   'future',
#   'shock',
#   'compendium',
#   'of',
#   'essays',
#   'in',
#   't',
#   '...'],
#  ['tickets', 'on', 'sale', 'aftershock', 'nowplaying', 'khdradio'],
#  ['come', 'with', 'us', 'to', 'aftershock'],
#  ['oo', 'i', 'think', 'i', 'felt', 'your', 'aftershock'],
#  ['a',
#   'quick',
#   'comparison',
#   'of',
#   'the',
#   'ongoing',
#   'm',
#   'puerto',
#   'rico',
#   'earthquake',
#   'sequence',
#   'and',
#   'the',
#   'm',
#   'central',
#   'california',
#   'sequenc',
#   '...'],
#  ['why',
#   'are',
#   'puerto',
#   'ricans',
#   'refusing',
#   'to',
#   'go',
#   'home',
#   'aside',
#   'from',
#   'the',
#   'aftershock',
#   'just',
#   'now',
#   'the',
#   'ground',
#   'in',
#   'southwest',
#   'puerto',
#   'rico',
#   'has',
#   '...'],
#  ['inception',
#   'the',
#   'social',
#   'network',
#   'easy',
#   'a',
#   'black',
#   'swan',
#   'toy',
#   'story',
#   'the',
#   'kids',
#   'are',
#   'all',
#   'right',
#   'aftershock'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['a', 'other', 'hard', 'hit'],
#  ['musharaf',
#   'verdict',
#   'was',
#   'just',
#   'mild',
#   'aftershock',
#   'of',
#   'extension',
#   'one',
#   'should',
#   'not',
#   'worry',
#   'what',
#   'comes',
#   'after',
#   'extention'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['kumera',
#   'yellow',
#   'aftershock',
#   'phfossil',
#   'featured',
#   'in',
#   'bankbtn',
#   'good',
#   'living',
#   'magazine',
#   'photography',
#   'stylist',
#   'shino',
#   '...'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['please', 'pray', 'for', 'puertorico'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['i', 'snova', 'o', 'krizise', 'demografii', 'yakovz'],
#  ['darkake',
#   'yeek',
#   'possessor',
#   'was',
#   'killed',
#   'by',
#   'possession',
#   'aftershock',
#   'on',
#   'ritches',
#   'tunnels'],
#  ['check',
#   'out',
#   'my',
#   'latest',
#   'video',
#   'superzero',
#   'vol',
#   'closer',
#   'look',
#   'a',
#   'closer',
#   'look',
#   'at',
#   'superzero',
#   'vol',
#   'by',
#   'am',
#   '...'],
#  ['might', 'be', 'a', 'small', 'aftershock', 'i', 'didnt', 'feel', 'anything'],
#  ['stay',
#   'informed',
#   'stay',
#   'engaged',
#   'with',
#   'whats',
#   'going',
#   'on',
#   'in',
#   'puertorico',
#   'after',
#   'the',
#   'earthquake',
#   'the',
#   'usgs',
#   "'",
#   'day',
#   'aftershock',
#   's',
#   '...'],
#  ['this',
#   'isnt',
#   'good',
#   'i',
#   'feel',
#   'for',
#   'the',
#   'people',
#   'of',
#   'puerto',
#   'rico'],
#  ['aftershock',
#   'vapor',
#   'pro',
#   'review',
#   '-',
#   'aussie',
#   'aussie',
#   'aussie',
#   'powerupau'],
#  ['puerto',
#   'rico',
#   'worker',
#   'explains',
#   'earthquake',
#   'aftershock',
#   'pleading',
#   'to',
#   'go',
#   'viral',
#   'via'],
#  ['this',
#   'is',
#   'an',
#   'unfathomable',
#   'number',
#   'i',
#   'lived',
#   'through',
#   'a',
#   'large',
#   'earthquake',
#   'and',
#   'we',
#   'slept',
#   'under',
#   'the',
#   'table',
#   'for',
#   'one',
#   'terrible',
#   'night',
#   '...'],
#  ['nah', 'i', 'need', 'calm', 'down'],
#  ['thinking',
#   'about',
#   'how',
#   'some',
#   'spat',
#   'blood',
#   'at',
#   'me',
#   'during',
#   'marilyn',
#   "manson's",
#   'set',
#   'at',
#   'aftershock'],
#  ['if',
#   'two',
#   'quakes',
#   'have',
#   'about',
#   'the',
#   'same',
#   'magnitude',
#   'you',
#   'cannot',
#   'say',
#   'one',
#   'is',
#   'the',
#   'others',
#   'preshock',
#   'or',
#   'aftershock',
#   'only',
#   'when',
#   'one',
#   'is',
#   'obv',
#   '...'],
#  ['an',
#   'mm',
#   'aftershock',
#   'happens',
#   'within',
#   'days',
#   'after',
#   'an',
#   'mm',
#   'main',
#   'shock',
#   'if',
#   'you',
#   'can',
#   'predict',
#   'it',
#   'then',
#   'you',
#   'can',
#   'say',
#   'it',
#   'is',
#   'an',
#   '...'],
#  ['i',
#   'dont',
#   'think',
#   'silivri',
#   'm',
#   'is',
#   'an',
#   'aftershock',
#   'of',
#   'the',
#   'silivri',
#   'm',
#   'a',
#   'few',
#   'months',
#   'ago',
#   'quake',
#   'professors',
#   'always',
#   'say',
#   'such',
#   'nonsen',
#   '...'],
#  ['i',
#   'think',
#   "it's",
#   'an',
#   'aftershock',
#   'from',
#   "'",
#   's',
#   'lyrical',
#   'beat',
#   'down',
#   'brent',
#   'never',
#   'recovered'],
#  ['apex',
#   'is',
#   'all',
#   'about',
#   'separating',
#   'from',
#   'monarch',
#   "they're",
#   '"',
#   'separation',
#   'well',
#   'from',
#   'my',
#   'theory',
#   'on',
#   'how',
#   'mechagod',
#   '...'],
#  ['thinking',
#   'about',
#   'how',
#   'some',
#   'spat',
#   'blood',
#   'at',
#   'me',
#   'during',
#   'marilyn',
#   "manson's",
#   'set',
#   'at',
#   'aftershock'],
#  ['or',
#   'sending',
#   'my',
#   'mate',
#   'simon',
#   'to',
#   'the',
#   'bar',
#   'and',
#   'asking',
#   'for',
#   'a',
#   'guiness',
#   'but',
#   'ending',
#   'up',
#   'with',
#   'a',
#   'carlsberg',
#   'export',
#   'and',
#   'a',
#   'mint',
#   'after',
#   '...'],
#  ['usgs',
#   'earthquake',
#   'experts',
#   'are',
#   'in',
#   'puertorico',
#   'installing',
#   'temporary',
#   'seismometers',
#   'to',
#   'help',
#   'track',
#   'seismic',
#   'events',
#   'including',
#   'a',
#   'jan',
#   'ma',
#   '...'],
#  ['puerto', 'rico', 'hit', 'by', 'another', 'magnitude', 'aftershock', 'kyma'],
#  ['over',
#   'the',
#   'weekend',
#   'puerto',
#   'rico',
#   'was',
#   'struck',
#   'by',
#   'a',
#   'aftershock',
#   'causing',
#   'more',
#   'damage',
#   'to',
#   'homes',
#   'and',
#   'schools',
#   'and',
#   'leaving',
#   'thou',
#   '...'],
#  ['how', 'could', 'you', 'leave', 'when', 'i', 'gave', 'you', 'my', 'all'],
#  ['for',
#   'the',
#   'full',
#   'experience',
#   'start',
#   'with',
#   'this',
#   'one',
#   'st',
#   'in',
#   'the',
#   'series',
#   'food',
#   'was',
#   'running',
#   'low',
#   'to',
#   'save',
#   'the',
#   'young',
#   'the',
#   'governor',
#   '...'],
#  ['the',
#   'magnitude',
#   'quake',
#   'in',
#   'puertorico',
#   'this',
#   'morning',
#   'caused',
#   'our',
#   'day',
#   'aftershock',
#   'forecast',
#   'to',
#   'change',
#   'we',
#   'now',
#   'estimate',
#   'an',
#   'increased',
#   '...'],
#  ['we',
#   'continue',
#   'to',
#   'update',
#   'our',
#   'day',
#   'aftershock',
#   'forecast',
#   'scenarios',
#   'for',
#   'puertorico',
#   'forecasts',
#   'are',
#   'posted',
#   'in',
#   'both',
#   'english'],
#  ['another',
#   'aftershock',
#   'has',
#   'hit',
#   'puerto',
#   'rico',
#   'after',
#   'last',
#   'night',
#   'people',
#   'cannot',
#   'go',
#   'home',
#   'if',
#   'they',
#   'even',
#   'have',
#   'one',
#   'they',
#   'have',
#   'no',
#   'po',
#   '...'],
#  ['aftershock',
#   'comics',
#   'we',
#   'prefer',
#   'working',
#   'in',
#   'partnership',
#   'with',
#   'our',
#   'creators',
#   'to',
#   'build',
#   'out',
#   'that',
#   'team',
#   'from',
#   'the',
#   'ground',
#   'up'],
#  ['did',
#   'the',
#   'other',
#   'earthquakeaftershock',
#   'mess',
#   'up',
#   'the',
#   'power',
#   'again'],
#  ['aftershock', 'forecast', 'for', 'puerto', 'rico'],
#  ['like', 'iran', 'shooting', 'an', 'airplane', 'was', 'an', 'accident'],
#  ['bing', 'bong', 'airplane', 'accident', 'remix'],
#  ['morgan',
#   'is',
#   'surprised',
#   'to',
#   'see',
#   'shaun',
#   'back',
#   'at',
#   'work',
#   'already',
#   'and',
#   'offers',
#   'her',
#   'condolences',
#   'on',
#   'his',
#   'dad',
#   'shaun',
#   'says',
#   'the',
#   'airplan',
#   '...'],
#  ["that's",
#   'a',
#   'load',
#   'of',
#   'rubbish',
#   'there',
#   'was',
#   'never',
#   'an',
#   'imminent',
#   'threat',
#   'jesus',
#   'christiran',
#   'sho',
#   '...'],
#  ['actually',
#   'blocking',
#   'the',
#   'internet',
#   'was',
#   'just',
#   'an',
#   'accident',
#   'you',
#   'know',
#   'just',
#   'like',
#   'when',
#   'iran',
#   'shot',
#   'down',
#   'the',
#   'ukrainian',
#   'airplane'],
#  ['conclusion',
#   'on',
#   'previous',
#   'page',
#   'is',
#   'incorrect',
#   'imho',
#   '"',
#   'the',
#   'witness',
#   'observations',
#   'of',
#   'a',
#   'streak',
#   'of',
#   'light',
#   'we',
#   '...'],
#  ['the',
#   'celebrities',
#   'in',
#   'iran',
#   'that',
#   'are',
#   'very',
#   'sadly',
#   'about',
#   'our',
#   'compatriots',
#   'that',
#   'killed',
#   'with',
#   'downing',
#   'uk',
#   'airplanenot',
#   'only',
#   'di',
#   '...'],
#  ['so',
#   'iranian',
#   'radars',
#   'cannot',
#   'tell',
#   'the',
#   'difference',
#   'between',
#   'an',
#   'incoming',
#   'missile',
#   'and',
#   'an',
#   'out',
#   'going',
#   'ukrainian',
#   'airplane',
#   'what',
#   '...'],
#  ['had',
#   'a',
#   'look',
#   'at',
#   'your',
#   'timeline',
#   'i',
#   'see',
#   'you',
#   'hate',
#   'my',
#   'coun',
#   '...'],
#  ['military',
#   'mistakes',
#   'usmilitary',
#   'shot',
#   'down',
#   'an',
#   'iranian',
#   'passenger',
#   'airplane',
#   'iranian',
#   'military',
#   'shot',
#   'down',
#   'an',
#   'ukr',
#   '...'],
#  ['secret',
#   'antispying',
#   'services',
#   'in',
#   'the',
#   'middle',
#   'east',
#   'should',
#   'be',
#   'on',
#   'high',
#   'alert',
#   'the',
#   'demolition',
#   'of',
#   'the',
#   'commercial',
#   'airplane',
#   'u',
#   '...'],
#  ['my',
#   'friend',
#   'i',
#   'live',
#   'here',
#   'believe',
#   'me',
#   'its',
#   'our',
#   'basic',
#   'rights',
#   'that',
#   'know',
#   'what',
#   'happened',
#   '...'],
#  ['secret',
#   'antispying',
#   'services',
#   'in',
#   'the',
#   'middle',
#   'east',
#   'should',
#   'be',
#   'on',
#   'high',
#   'alert',
#   'the',
#   'demolition',
#   'of',
#   'the',
#   'commercial',
#   'airpl',
#   '...'],
#  ['how',
#   'is',
#   'it',
#   'that',
#   'iran',
#   'fired',
#   'between',
#   'and',
#   'surface',
#   'to',
#   'surface',
#   'missiles',
#   '...',
#   'then',
#   'fired',
#   'a',
#   'surface',
#   'to',
#   'air',
#   'missile',
#   'at',
#   '...'],
#  ['basically',
#   'you',
#   'killed',
#   'the',
#   'general',
#   'put',
#   'the',
#   'whole',
#   'country',
#   'into',
#   'a',
#   'confusing',
#   'status',
#   'they',
#   'shoot',
#   'a',
#   'civ',
#   '...'],
#  ['no',
#   'i',
#   'was',
#   'referring',
#   'to',
#   'the',
#   'shooting',
#   'down',
#   'of',
#   'the',
#   'airplane',
#   'i',
#   'really',
#   'do',
#   '...'],
#  ['no',
#   'i',
#   'was',
#   'referring',
#   'to',
#   'the',
#   'shooting',
#   'down',
#   'of',
#   'the',
#   'airplane',
#   'i',
#   '...'],
#  ['and',
#   'anyone',
#   'who',
#   'believes',
#   'that',
#   'incident',
#   'was',
#   'an',
#   'accident',
#   'is',
#   'an',
#   'idiot',
#   'an',
#   'airplane',
#   'at',
#   'approx',
#   'fee',
#   '...'],
#  ['and',
#   'anyone',
#   'who',
#   'believes',
#   'that',
#   'incident',
#   'was',
#   'an',
#   'accident',
#   'is',
#   'an',
#   'idiot',
#   'an',
#   'airplane',
#   'at',
#   'approx',
#   '...'],
#  ['iran',
#   'did',
#   'not',
#   'blow',
#   'up',
#   'an',
#   'airplane',
#   'by',
#   'accident',
#   'they',
#   'intended',
#   'for',
#   'it',
#   'to',
#   'be',
#   'shot',
#   'down',
#   'the',
#   'accident',
#   'is',
#   'that',
#   'it',
#   'was',
#   'a',
#   'civilian',
#   'aircraft'],
#  ['but', 'the', 'airplane', 'accident'],
#  ['mr',
#   'm',
#   'u',
#   'hold',
#   'ptrump',
#   'accountable',
#   'for',
#   'the',
#   'airplane',
#   'accidentwe',
#   'r',
#   'very',
#   'sad',
#   'toobut',
#   'pls',
#   "don't",
#   'tweet',
#   'abo',
#   '...'],
#  ['just',
#   'dial',
#   'tollfree',
#   'from',
#   'your',
#   'phone',
#   'in',
#   'the',
#   'event',
#   'that',
#   'you',
#   'wish',
#   'to',
#   'report',
#   'fire',
#   'flood',
#   'theft',
#   'armed',
#   'robbery',
#   'kidnap',
#   '...'],
#  ['just',
#   'dial',
#   'tollfree',
#   'from',
#   'your',
#   'phone',
#   'in',
#   'the',
#   'event',
#   'that',
#   'you',
#   'wish',
#   'to',
#   'report',
#   'fire',
#   'flood',
#   'theft',
#   'armed',
#   'robbery',
#   'k',
#   '...'],
#  ['so',
#   'iran',
#   'can',
#   'shoot',
#   'down',
#   'a',
#   'commercial',
#   'airplane',
#   'and',
#   'claim',
#   'it',
#   'was',
#   'an',
#   'accident',
#   'does',
#   'anyone',
#   'really',
#   'believe',
#   'that'],
#  ['you',
#   'may',
#   'be',
#   'unaware',
#   'that',
#   'cnd',
#   'is',
#   'currently',
#   'in',
#   'mourning',
#   'canadians',
#   'were',
#   'downed',
#   'in',
#   'an',
#   'airplane',
#   'by',
#   'accident',
#   'in',
#   'iran',
#   'flag',
#   '...'],
#  ['sorry',
#   'for',
#   'your',
#   'loss',
#   'iran',
#   'should',
#   'never',
#   'have',
#   'shot',
#   'the',
#   'airplane',
#   'out',
#   'of',
#   'the',
#   'sky',
#   "'",
#   'accident',
#   "'",
#   'they',
#   'say'],
#  ['it',
#   'wasnt',
#   'iranians',
#   'knew',
#   'when',
#   'takeoff',
#   'was',
#   'happening',
#   'amp',
#   'they',
#   'knew',
#   'the',
#   'airplane',
#   'manufacturer',
#   'was',
#   'american',
#   '...'],
#  ['mass',
#   'antigovernment',
#   'protests',
#   'erupt',
#   'in',
#   'iran',
#   'after',
#   'leaders',
#   'admit',
#   'to',
#   'shooting',
#   'down',
#   'airliner',
#   'still',
#   'cannot',
#   'believe',
#   'w',
#   '...'],
#  ['i',
#   'read',
#   'the',
#   'whole',
#   'thread',
#   "he's",
#   'blaming',
#   'trump',
#   'for',
#   'iran',
#   'shooting',
#   'down',
#   'an',
#   'ai',
#   '...'],
#  ['airplane',
#   'accident',
#   'answers',
#   'the',
#   'us',
#   'designated',
#   'the',
#   'iranian',
#   'government',
#   'as',
#   'terrorists',
#   'and',
#   'ha',
#   '...'],
#  ['hey',
#   'got',
#   'some',
#   'swamp',
#   'land',
#   'for',
#   'sale',
#   'you',
#   'are',
#   'either',
#   'naive',
#   'or',
#   'just',
#   'plain',
#   'stupid',
#   'which',
#   'is',
#   'it',
#   'iran',
#   'downing',
#   't',
#   '...'],
#  ['perhaps',
#   'prodded',
#   'by',
#   'others',
#   'zelensky',
#   'decides',
#   'ukraine',
#   'has',
#   'nothing',
#   'to',
#   'lose',
#   'by',
#   'piling',
#   'onto',
#   'iran',
#   'never',
#   'seen',
#   'so',
#   'many',
#   'op',
#   '...'],
#  ['as',
#   'a',
#   'canadian',
#   'i',
#   'am',
#   'very',
#   'concerned',
#   'the',
#   'airplane',
#   'that',
#   'was',
#   'shot',
#   'down',
#   'by',
#   'accident',
#   'had',
#   'canadians',
#   'many',
#   'of',
#   'iranian',
#   '...'],
#  ['shooting',
#   'an',
#   'airplane',
#   'down',
#   'by',
#   'accident',
#   'is',
#   'bullshit',
#   'just',
#   'like',
#   'accidental',
#   'shootings',
#   'of',
#   'firearms',
#   'especially',
#   'since',
#   '...'],
#  ['odd',
#   'how',
#   'the',
#   'iranians',
#   'accidentally',
#   'blew',
#   'up',
#   'the',
#   'airplane',
#   'after',
#   'take',
#   'off',
#   'was',
#   'someone',
#   'just',
#   'playing',
#   'with',
#   '...'],
#  ['as',
#   'a',
#   'canadian',
#   'i',
#   'am',
#   'very',
#   'concerned',
#   'the',
#   'airplane',
#   'that',
#   'was',
#   'shot',
#   'down',
#   'by',
#   'accident',
#   'had',
#   'canadians',
#   'many',
#   '...'],
#  ['and',
#   'no',
#   'excuse',
#   'for',
#   'shooting',
#   'down',
#   'a',
#   'commercial',
#   'airplane',
#   'with',
#   'innocent',
#   'civilians',
#   'on',
#   'oh',
#   'sorry',
#   'jeremy',
#   'as',
#   'you',
#   'say',
#   'it',
#   'was',
#   'an',
#   '...'],
#  ['you',
#   'beat',
#   'me',
#   'to',
#   'this',
#   'response',
#   'you',
#   'have',
#   'to',
#   'track',
#   'an',
#   'airplane',
#   'with',
#   'a',
#   'surface',
#   'to',
#   'air',
#   'missile',
#   '...'],
#  ['it',
#   'is',
#   'unimaginable',
#   'to',
#   'have',
#   'people',
#   'gone',
#   'in',
#   'one',
#   'accident',
#   'how',
#   'could',
#   'anyone',
#   'point',
#   'a',
#   'surface',
#   'to',
#   'air',
#   'missile',
#   'at',
#   'a',
#   '...'],
#  ['so',
#   'it',
#   'was',
#   'just',
#   'an',
#   'accident',
#   'that',
#   'iran',
#   'rocketed',
#   'an',
#   'airplane',
#   'killing',
#   'people',
#   'and',
#   'libs',
#   'defending',
#   'it',
#   'like',
#   "that's",
#   'ok',
#   'b',
#   '...'],
#  ['and',
#   'no',
#   'excuse',
#   'for',
#   'shooting',
#   'down',
#   'a',
#   'commercial',
#   'airplane',
#   'with',
#   'innocent',
#   'civilians',
#   'on',
#   'oh',
#   'sorry',
#   'jeremy',
#   'as',
#   'you',
#   'say',
#   'it',
#   '...'],
#  ['well',
#   "let's",
#   'see',
#   'we',
#   'know',
#   'so',
#   'far',
#   'the',
#   'body',
#   'count',
#   'of',
#   'demonstrators',
#   'was',
#   'over',
#   '...'],
#  ['you',
#   'beat',
#   'me',
#   'to',
#   'this',
#   'response',
#   'you',
#   'have',
#   'to',
#   'track',
#   'an',
#   'airplane',
#   'with',
#   'a',
#   'surface',
#   'to',
#   'air',
#   'missi',
#   '...'],
#  ['good',
#   'lord',
#   'yeah',
#   'it',
#   'was',
#   'an',
#   'accident',
#   'the',
#   'airplane',
#   'didnt',
#   'give',
#   'the',
#   'missile',
#   'the',
#   'right',
#   'away'],
#  ['the',
#   'iranian',
#   'leadership',
#   'has',
#   'downed',
#   'the',
#   'commercial',
#   'airplane',
#   'on',
#   'purpose',
#   'who',
#   'are',
#   'they',
#   'kidding',
#   'by',
#   'saying',
#   'it',
#   'was',
#   'by',
#   'accident'],
#  ['ooh',
#   'look',
#   'nyt',
#   'became',
#   'a',
#   'lawyer',
#   'for',
#   'the',
#   'iranian',
#   'regime',
#   'what',
#   'a',
#   'stupid',
#   'newspaper',
#   "it's",
#   'now',
#   'time',
#   'there',
#   'are',
#   'vi',
#   '...'],
#  ['how',
#   'exactly',
#   'does',
#   'one',
#   'accidentally',
#   'fire',
#   'a',
#   'rocket',
#   'at',
#   'an',
#   'airplane',
#   'leaving',
#   'your',
#   'own',
#   'countries',
#   'airport',
#   'this',
#   '...'],
#  ['so',
#   'they',
#   'saying',
#   'shooting',
#   'down',
#   'that',
#   'airplane',
#   'w',
#   'innocent',
#   'ppl',
#   'was',
#   'an',
#   'accident',
#   'bruh'],
#  ['there',
#   'were',
#   'nuclear',
#   'physicists',
#   'on',
#   'that',
#   'airplane',
#   'it',
#   'was',
#   'no',
#   'accident'],
#  ['and',
#   'his',
#   'murderous',
#   'friends',
#   'shoot',
#   'down',
#   'an',
#   'airplane',
#   'by',
#   'accident',
#   'killing',
#   'around',
#   'innocent',
#   'people',
#   'but',
#   'wa',
#   '...'],
#  ['yup',
#   'and',
#   'the',
#   'us',
#   'once',
#   'shot',
#   'down',
#   'an',
#   'iranian',
#   'airplane',
#   'by',
#   'accident',
#   'and',
#   "we've",
#   'been',
#   'supp',
#   '...'],
#  ['united',
#   'states',
#   'downs',
#   'an',
#   'iranian',
#   'terrorist',
#   'and',
#   'the',
#   'world',
#   'press',
#   'dedicates',
#   'tons',
#   'of',
#   'articles',
#   'on',
#   'the',
#   'life',
#   'he',
#   'lived',
#   'but',
#   'the',
#   'ira',
#   '...'],
#  ['besides',
#   'the',
#   'airplane',
#   'being',
#   'shot',
#   'down',
#   'by',
#   'accident',
#   'other',
#   'things',
#   'are',
#   'habbening',
#   'also',
#   'highlevel',
#   'proiran',
#   'militi',
#   '...'],
#  ['cbc',
#   'news',
#   'just',
#   'said',
#   'there',
#   'was',
#   'an',
#   'operator',
#   'on',
#   'a',
#   'missile',
#   'launcher',
#   'that',
#   'shot',
#   'down',
#   'the',
#   'airplane',
#   'cockpit',
#   'was',
#   'taken',
#   'out',
#   '...'],
#  ['consider',
#   'gt',
#   'how',
#   'does',
#   'a',
#   'person',
#   'with',
#   'a',
#   'video',
#   'camera',
#   'know',
#   'where',
#   'and',
#   'when',
#   'to',
#   'record',
#   'an',
#   'attack',
#   'before',
#   'there',
#   'was',
#   'any',
#   'indication',
#   '...'],
#  ['besides',
#   'the',
#   'airplane',
#   'being',
#   'shot',
#   'down',
#   'by',
#   'accident',
#   'other',
#   'things',
#   'are',
#   'habbening',
#   'also',
#   'highlevel',
#   'proir',
#   '...'],
#  ['yeah',
#   'yer',
#   'well',
#   'prepared',
#   'hit',
#   'a',
#   'few',
#   'buildings',
#   'amp',
#   'knocked',
#   'down',
#   'yer',
#   'own',
#   'airplane',
#   'by',
#   'accident',
#   'better',
#   'keep',
#   'd',
#   '...'],
#  ['if',
#   'the',
#   'shooting',
#   'down',
#   'of',
#   'the',
#   'plane',
#   'was',
#   'an',
#   'accident',
#   'human',
#   'error',
#   'why',
#   'were',
#   'the',
#   'iranians',
#   'shooting',
#   'mi',
#   '...'],
#  ['this',
#   'attack',
#   'n',
#   'on',
#   'an',
#   'airplane',
#   'that',
#   'had',
#   'just',
#   'taken',
#   'off',
#   'was',
#   'no',
#   'accident',
#   'iran',
#   'wants',
#   'the',
#   'world',
#   'to',
#   'know',
#   'there',
#   'will',
#   'be',
#   'co',
#   '...'],
#  ['grover', 'airplane', 'accident', 'doctor'],
#  ['trump',
#   'in',
#   'accident',
#   'crash',
#   'airplane',
#   'ukraine',
#   'is',
#   'the',
#   'main',
#   'factor',
#   'as',
#   'the',
#   'most',
#   'powerful',
#   'person',
#   'in',
#   'the',
#   'world',
#   'whose',
#   'count',
#   '...'],
#  ['trump',
#   'in',
#   'accident',
#   'crash',
#   'airplane',
#   'ukraine',
#   'is',
#   'the',
#   'main',
#   'factor',
#   'as',
#   'the',
#   'most',
#   'powerful',
#   'person',
#   'in',
#   'the',
#   'world',
#   'whose',
#   '...'],
#  ['although',
#   'its',
#   'late',
#   'i',
#   'extend',
#   'my',
#   'condolences',
#   'to',
#   'all',
#   'the',
#   'families',
#   'of',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'ukrainian',
#   'airplane',
#   'falling',
#   'inclu',
#   '...'],
#  ['iranian',
#   'military',
#   'admitted',
#   'it',
#   'shot',
#   'down',
#   'ukrainian',
#   'airplane',
#   'by',
#   'missiles',
#   'accidentally',
#   'it',
#   'is',
#   'not',
#   'an',
#   'accident',
#   'it',
#   'is',
#   'a',
#   'crim',
#   '...'],
#  ['so',
#   'much',
#   'talk',
#   'about',
#   'ukraine',
#   'airplane',
#   'within',
#   'iran',
#   'usa',
#   'conflict',
#   'while',
#   'conflict',
#   'wise',
#   'this',
#   'is',
#   'irrelevant',
#   'what',
#   'is',
#   'mo',
#   '...'],
#  ['although',
#   'its',
#   'late',
#   'i',
#   'extend',
#   'my',
#   'condolences',
#   'to',
#   'all',
#   'the',
#   'families',
#   'of',
#   'the',
#   'victims',
#   'of',
#   'the',
#   'ukrainian',
#   'airplane',
#   'falling',
#   '...'],
#  ['iran',
#   'shot',
#   'down',
#   'an',
#   'airplane',
#   'full',
#   'of',
#   'innocent',
#   'people',
#   'say',
#   'what',
#   'you',
#   'want',
#   'about',
#   'trump',
#   'but',
#   "that's",
#   'not',
#   'an',
#   'appropriate',
#   'r',
#   '...'],
#  ['she',
#   'is',
#   'still',
#   'silent',
#   'about',
#   'the',
#   'killing',
#   'of',
#   'innocent',
#   'people',
#   'in',
#   'iran',
#   'iranian',
#   'military',
#   'admitted',
#   'it',
#   'shot',
#   'down',
#   'ukrainian',
#   'a',
#   '...'],
#  ['the',
#   'iranians',
#   'chose',
#   'the',
#   'day',
#   'and',
#   'time',
#   'to',
#   'send',
#   'missiles',
#   'inside',
#   'iraq',
#   'and',
#   'they',
#   'also',
#   'controlled',
#   'the',
#   '...'],
#  ['was',
#   'the',
#   'airplane',
#   'on',
#   'a',
#   'routine',
#   'flight',
#   'path',
#   'from',
#   'the',
#   'airport',
#   'one',
#   'would',
#   'think',
#   'those',
#   'that',
#   'shot',
#   'it',
#   'down',
#   'would',
#   'be',
#   'fam',
#   '...'],
#  ['germanys',
#   'foreign',
#   'minister',
#   'heiko',
#   'maas',
#   'says',
#   'it',
#   'must',
#   'be',
#   'assumed',
#   'the',
#   'airplane',
#   'crash',
#   'in',
#   'iran',
#   'was',
#   'a',
#   'terrible',
#   'accident'],
#  ['how',
#   'about',
#   'some',
#   'compassion',
#   'for',
#   'the',
#   'families',
#   'of',
#   'the',
#   'ukrainian',
#   'airplane',
#   'shot',
#   'down',
#   'by',
#   'accident',
#   '...'],
#  ['how',
#   'about',
#   'some',
#   'compassion',
#   'for',
#   'the',
#   'families',
#   'of',
#   'the',
#   'ukrainian',
#   'airplane',
#   'shot',
#   'down',
#   'by',
#   'accident'],
#  ['fire',
#   'engulfs',
#   'ambulance',
#   'conveying',
#   'corpse',
#   'of',
#   'catholic',
#   "priest's",
#   'mother',
#   'streetjournal'],
#  ['is',
#   'it',
#   'racist',
#   'to',
#   'be',
#   'concerned',
#   'that',
#   'this',
#   'is',
#   'correct',
#   '...',
#   'residents',
#   'in',
#   'birmingham',
#   'cant',
#   'speak',
#   'english',
#   'birmingham',
#   'is',
#   'england',
#   '...'],
#  ['waarland', 'ambulance', 'p', 'a', 'rit', 'sabinahof', 'waarland'],
#  ['usdjpy',
#   'despite',
#   'richter',
#   'scale',
#   'overbought',
#   'fxstreet',
#   'line',
#   'up',
#   'swissquote',
#   'bullish',
#   'long',
#   'jason',
#   'sen',
#   'mr',
#   'ambulance',
#   'chaser',
#   'b',
#   '...'],
#  ['usdjpy',
#   'despite',
#   'richter',
#   'scale',
#   'overbought',
#   'fxstreet',
#   'line',
#   'up',
#   'swissquote',
#   'bullish',
#   'long',
#   'jason',
#   'sen',
#   'mr',
#   'ambulance',
#   'cha',
#   '...'],
#  ['the',
#   'untamed',
#   'boys',
#   'singing',
#   '"',
#   'love',
#   'siren',
#   '"',
#   'from',
#   'my',
#   'ambulance',
#   'theuntamedboysinbkk'],
#  ['or', 'pulling', 'over', 'for', 'an', 'ambulance'],
#  ['i',
#   'hope',
#   "there's",
#   'going',
#   'to',
#   'be',
#   'an',
#   'ambulance',
#   'waiting',
#   'at',
#   'the',
#   'bottom',
#   'because',
#   "there's",
#   'no',
#   'way',
#   'that',
#   'fat',
#   'lump',
#   'can',
#   'cli',
#   '...'],
#  ['raktidaichern',
#   'my',
#   'ambulance',
#   'cover',
#   'is',
#   'coming',
#   'theuntamedboys',
#   'ambassador',
#   'for',
#   'thai',
#   'spring',
#   'festival',
#   'the',
#   'delightful',
#   '...'],
#  ['when',
#   'driving',
#   'drunk',
#   'you',
#   'can',
#   'choose',
#   'your',
#   'way',
#   'to',
#   'come',
#   'back',
#   'home',
#   'a',
#   'taxi',
#   'b',
#   '...'],
#  ['yer',
#   'severe',
#   'ambulance',
#   'ramping',
#   'under',
#   'fundingresourcing',
#   '...'],
#  ['zulaykhas',
#   'son',
#   'was',
#   'an',
#   'ambulance',
#   'driver',
#   'who',
#   'was',
#   'killed',
#   'in',
#   'a',
#   'suicide',
#   'attack',
#   'in',
#   'maimana',
#   'faryab',
#   'everyday',
#   'she',
#   'visits',
#   'the',
#   'ambu',
#   '...'],
#  ['first',
#   'of',
#   'all',
#   'he',
#   'was',
#   'not',
#   'taken',
#   'to',
#   'no',
#   'damn',
#   'hospital',
#   'that',
#   'man',
#   'died',
#   'in',
#   'walmart',
#   'with',
#   'the',
#   'ambulance',
#   'outside',
#   'they',
#   'was',
#   'more',
#   'focuse',
#   '...'],
#  ['jinu',
#   'are',
#   'you',
#   'okay',
#   'you',
#   'hit',
#   'your',
#   'head',
#   'and',
#   'fainted',
#   'do',
#   'you',
#   'remember',
#   'anything',
#   'yoon',
#   'only',
#   'the',
#   'ambulance',
#   'ride',
#   'to',
#   'the',
#   'hospi',
#   '...'],
#  ['what',
#   'has',
#   'it',
#   'come',
#   'to',
#   "we've",
#   'recently',
#   'had',
#   'fuel',
#   'stolen',
#   'from',
#   'ambulance',
#   'vehicles',
#   'and',
#   'damage',
#   'to',
#   'a',
#   'staff',
#   'car',
#   'whilst',
#   'on',
#   'an',
#   'ambulanc',
#   '...'],
#  ['theyve', 'gone', 'ambulance', 'chasing', 'in', 'australia'],
#  ['and',
#   'drumroll',
#   'its',
#   'beach',
#   'girl',
#   'henry',
#   'tried',
#   'to',
#   'keep',
#   'pressure',
#   'on',
#   'the',
#   'wound',
#   'and',
#   'calls',
#   'for',
#   'an',
#   '...'],
#  ['what', 'racism', 'absolutely', 'delighted', '...'],
#  ['the',
#   'norovirus',
#   'is',
#   'like',
#   'a',
#   'detox',
#   'gets',
#   'all',
#   'the',
#   'crap',
#   'out',
#   'the',
#   'system',
#   'much',
#   'like',
#   'flushing',
#   'out',
#   'the',
#   'central',
#   'h',
#   '...'],
#  ['ooh',
#   'guys',
#   'do',
#   'you',
#   'know',
#   'where',
#   'in',
#   'gauteng',
#   'people',
#   'go',
#   'to',
#   'study',
#   'nursing',
#   'and',
#   'the',
#   'ambulance',
#   'nurses',
#   'who',
#   'keep',
#   'you',
#   'alive',
#   'in',
#   'transit',
#   '...'],
#  ['iranprotests',
#   'tehran',
#   'right',
#   'now',
#   'valiasr',
#   'intersection',
#   'is',
#   'where',
#   'the',
#   'special',
#   'forces',
#   'are',
#   'heading',
#   'to',
#   'the',
#   'paradise',
#   'ambulance',
#   '...'],
#  ['are',
#   'you',
#   'one',
#   'of',
#   'those',
#   'who',
#   'silently',
#   'pray',
#   'for',
#   'an',
#   'unknown',
#   'ambulance',
#   'passed',
#   'by'],
#  ['long',
#   'night',
#   'moms',
#   'sugar',
#   'dropped',
#   'to',
#   'so',
#   'dad',
#   'called',
#   'an',
#   'ambulance',
#   'no',
#   'fun',
#   'at',
#   'hospital',
#   'with',
#   'late',
#   'shift'],
#  ['if',
#   'you',
#   'have',
#   'norovirus',
#   'theres',
#   'no',
#   'place',
#   'like',
#   'home',
#   'the',
#   'winter',
#   'bug',
#   'is',
#   'unpleasant',
#   'but',
#   'usual',
#   'goes',
#   'away',
#   'after',
#   'a',
#   'coupl',
#   '...'],
#  ['i',
#   "don't",
#   'understand',
#   'how',
#   'jongkook',
#   'danced',
#   'like',
#   'that',
#   'and',
#   'was',
#   'not',
#   'breathing',
#   'heavily',
#   'at',
#   'the',
#   'end',
#   'of',
#   'his',
#   'sequence',
#   'while',
#   'lyi',
#   '...'],
#  ['unilorin',
#   'did',
#   'not',
#   'have',
#   'oxygen',
#   'a',
#   'whole',
#   'university',
#   'of',
#   'ilorin',
#   'not',
#   'having',
#   'oxygen',
#   'they',
#   'had',
#   'to',
#   'refer',
#   'us',
#   'to',
#   'uith',
#   'thinking',
#   'maybe',
#   't',
#   '...'],
#  ['"', 'ambulance', 'nurses', '"'],
#  ['angels',
#   'over',
#   'africa',
#   'a',
#   'netcare',
#   'air',
#   'ambulance',
#   'with',
#   'doctor',
#   'and',
#   'paramedic',
#   'has',
#   'been',
#   'activated',
#   'for',
#   'an',
#   'interhospitaltrans',
#   '...'],
#  ['for',
#   'all',
#   'your',
#   'ambulance',
#   'needs',
#   'call',
#   'us',
#   'today',
#   'on',
#   'our',
#   'tollfree',
#   'number'],
#  ['what',
#   'a',
#   'lovely',
#   'message',
#   'to',
#   'receive',
#   'thank',
#   'you',
#   'so',
#   'much'],
#  ['timely',
#   'action',
#   'during',
#   'accidents',
#   'can',
#   'save',
#   'someones',
#   'life',
#   'if',
#   'you',
#   'find',
#   'someone',
#   'with',
#   'injury',
#   'then',
#   'call',
#   'for',
#   'an',
#   'ambulance',
#   '...'],
#  ['when',
#   'technical',
#   'brains',
#   'speak',
#   'to',
#   'a',
#   'raging',
#   'debate',
#   'mostly',
#   'their',
#   'disposition',
#   'amp',
#   'knowledge',
#   'calms',
#   'the',
#   'storm',
#   'even',
#   'more',
#   '...'],
#  ['just',
#   'got',
#   'back',
#   'from',
#   'the',
#   'hospital',
#   'bc',
#   'i',
#   'accidentally',
#   'blended',
#   'my',
#   'finger',
#   'while',
#   'cooking',
#   'and',
#   'i',
#   'promised',
#   'the',
#   'ambulance',
#   'doctors',
#   'i',
#   'w',
#   '...'],
#  ['another',
#   'race',
#   'baiting',
#   'ambulance',
#   'chaser',
#   'exposed',
#   'this',
#   'is',
#   'racism',
#   'in',
#   'action',
#   'but',
#   'you',
#   'and',
#   'peop',
#   '...'],
#  ['ooh',
#   'guys',
#   'do',
#   'you',
#   'know',
#   'where',
#   'in',
#   'gauteng',
#   'people',
#   'go',
#   'to',
#   'study',
#   'nursing',
#   'and',
#   'the',
#   'ambulance',
#   'nurses',
#   'who',
#   'keep',
#   'you',
#   'alive',
#   'in',
#   't',
#   '...'],
#  ['nicki',
#   'minaj',
#   'single',
#   'handedly',
#   'annihilated',
#   'the',
#   'male',
#   'species',
#   'the',
#   'day',
#   'this',
#   'dropped'],
#  ['you', 'must', 'be', 'annihilated'],
#  ['basically',
#   'let',
#   'people',
#   'work',
#   'hard',
#   'for',
#   'their',
#   'money',
#   'save',
#   'invest',
#   'wisely',
#   'then',
#   'snatch',
#   'it',
#   'from',
#   'them',
#   'to',
#   'fu',
#   '...'],
#  ['thanks',
#   'no',
#   'offence',
#   'taken',
#   'but',
#   'really',
#   'the',
#   'choice',
#   'for',
#   'centre',
#   'left',
#   'parties',
#   'is',
#   'either',
#   're',
#   '...'],
#  ['the',
#   'commonest',
#   'line',
#   'in',
#   'most',
#   'naija',
#   'songs',
#   'that',
#   'has',
#   'now',
#   'become',
#   'annoying',
#   'is',
#   'the',
#   'way',
#   'you',
#   'whyne',
#   'e',
#   'dey',
#   'blow',
#   'my',
#   'mind',
#   'please',
#   '...'],
#  ['which',
#   'quranic',
#   'verse',
#   'did',
#   'the',
#   'leader',
#   'choose',
#   'for',
#   'qasem',
#   'soleimani',
#   'unique',
#   'moment',
#   'a',
#   'soldier',
#   'of',
#   'islam',
#   'who',
#   'tirelessly',
#   'foug',
#   '...'],
#  ["she's",
#   'not',
#   'wrong',
#   'the',
#   'only',
#   'way',
#   'aca',
#   'was',
#   'passed',
#   'was',
#   'because',
#   '...'],
#  ['you',
#   'get',
#   'ready',
#   'by',
#   'picking',
#   'your',
#   'weapon',
#   'of',
#   'choice',
#   'i',
#   'chose',
#   'a',
#   'lute',
#   'of',
#   'course',
#   'thinking',
#   'everything',
#   'will',
#   '...'],
#  ['actually',
#   'impossible',
#   'to',
#   'tell',
#   'whether',
#   'dan',
#   'or',
#   'boris',
#   'is',
#   'less',
#   'across',
#   'their',
#   'briefs',
#   'a',
#   'journalist',
#   'almost',
#   'any',
#   'journalist',
#   '...'],
#  ['zero',
#   'chance',
#   'of',
#   'any',
#   'of',
#   'those',
#   'candidates',
#   'winning',
#   'the',
#   'next',
#   'election',
#   'the',
#   'deluded',
#   'hard',
#   'left',
#   'will',
#   '...'],
#  ['good',
#   'riddance',
#   'to',
#   'bad',
#   'rubbish',
#   'just',
#   'like',
#   'well',
#   'be',
#   'saying',
#   'about',
#   'you',
#   'when',
#   'youre',
#   'annihilated',
#   'at',
#   'fedelection'],
#  ["haven't",
#   'the',
#   'likes',
#   'of',
#   'understood',
#   'yet',
#   'that',
#   'it',
#   'was',
#   'these',
#   'sht',
#   'policies',
#   'plus',
#   'out',
#   'of',
#   'touch',
#   '...'],
#  ['all',
#   'the',
#   'breasts',
#   'that',
#   'have',
#   'perished',
#   'in',
#   'the',
#   'name',
#   'of',
#   'a',
#   'a',
#   'bottle',
#   'of',
#   'poison',
#   'it',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'cry',
#   'it',
#   'makes',
#   'me',
#   'want',
#   't',
#   '...'],
#  ['httpstcoebfqbesi',
#   'yall',
#   'this',
#   'beautiful',
#   'delicate',
#   'tender',
#   'vampire',
#   'taejin',
#   'annihilated',
#   'me',
#   'tonight',
#   'it',
#   'is',
#   'the',
#   'most',
#   '...'],
#  ['just',
#   'reminiscing',
#   'about',
#   'the',
#   'time',
#   'i',
#   'annihilated',
#   'a',
#   'pb',
#   'and',
#   'made',
#   'it',
#   'look',
#   'easy',
#   'kg',
#   'feeling',
#   'fiine',
#   'bring',
#   'on',
#   'gpc',
#   '...'],
#  ['titans',
#   'raise',
#   'your',
#   'tridents',
#   'and',
#   'drink',
#   'to',
#   'victory',
#   'we',
#   'annihilated',
#   'our',
#   'enemies',
#   'yesterday',
#   'and',
#   'sent',
#   'them',
#   'to',
#   'hades',
#   'where',
#   'they',
#   '...'],
#  ['all',
#   'the',
#   'promises',
#   'that',
#   'have',
#   'perished',
#   'in',
#   'the',
#   'name',
#   'of',
#   'a',
#   'almond',
#   'it',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'cry',
#   'it',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'curse',
#   'des',
#   '...'],
#  ['sne',
#   'you',
#   'really',
#   'tryna',
#   'see',
#   'me',
#   'get',
#   'annihilated',
#   'dm',
#   'me',
#   'your',
#   'psn',
#   'bro'],
#  ['titans',
#   'raise',
#   'your',
#   'tridents',
#   'and',
#   'drink',
#   'to',
#   'victory',
#   'we',
#   'annihilated',
#   'our',
#   'enemies',
#   'yesterday',
#   'and',
#   'sent',
#   'them',
#   'to',
#   'hades',
#   'where',
#   '...'],
#  ['i',
#   'will',
#   'appreciate',
#   'the',
#   'bbc',
#   'igbo',
#   'when',
#   'it',
#   'starts',
#   'to',
#   'expose',
#   'how',
#   'britain',
#   'partook',
#   'in',
#   'the',
#   'biafra',
#   'genocide',
#   'were',
#   'over',
#   'millio',
#   '...'],
#  ['polls',
#   'mean',
#   'shit',
#   'all',
#   'hugh',
#   'they',
#   'were',
#   'wrong',
#   'massively',
#   'we',
#   'have',
#   'effectively',
#   'now',
#   'had',
#   'votes',
#   'leave',
#   'won',
#   '...'],
#  ['piers', 'morgan', 'annihilated', 'with', 'simple', 'logic'],
#  ['piers',
#   'morgan',
#   'annihilated',
#   'with',
#   'simple',
#   'logic',
#   'vegan',
#   'advocacy',
#   'on',
#   'good',
#   'morning',
#   'britain'],
#  ['piers',
#   'morgan',
#   'annihilated',
#   'with',
#   'simple',
#   'logic',
#   'vegan',
#   'advocacy'],
#  ['all',
#   'the',
#   'apples',
#   'that',
#   'have',
#   'perished',
#   'in',
#   'the',
#   'name',
#   'of',
#   'a',
#   'adderall',
#   'pill',
#   'it',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'cry',
#   'it',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'curs',
#   '...'],
#  ['we',
#   'win',
#   'the',
#   'federal',
#   'judge',
#   'lifted',
#   'the',
#   'tro',
#   'we',
#   'can',
#   'build',
#   'in',
#   'the',
#   'floodplain',
#   'this',
#   'will',
#   'change',
#   'the',
#   'game',
#   'the',
#   'judge',
#   'absolutely',
#   '...'],
#  ['oppenheimer',
#   'annihilated',
#   'him',
#   'i',
#   'was',
#   'done',
#   'when',
#   'he',
#   'referenced',
#   'mistress',
#   'deaths',
#   'dislike',
#   'of',
#   'thanos'],
#  ['and',
#   'i',
#   'lost',
#   'in',
#   'our',
#   'big',
#   'team',
#   'event',
#   'points',
#   'out',
#   'of',
#   'with',
#   'a',
#   'pretty',
#   'nice',
#   'list',
#   'its',
#   'like',
#   'i',
#   'was',
#   'annihilated',
#   'inside'],
#  ['theyd', 'get', 'annihilated', 'by', 'miami'],
#  ['being',
#   'an',
#   'ally',
#   'of',
#   'the',
#   'us',
#   'means',
#   'you',
#   'too',
#   'can',
#   'be',
#   'annihilated',
#   'at',
#   'any',
#   'minute',
#   'just',
#   'look',
#   'at',
#   'the',
#   'kurds'],
#  ['the',
#   'pores',
#   'on',
#   'my',
#   'nose',
#   'after',
#   'getting',
#   'annihilated',
#   'by',
#   'my',
#   'fingers',
#   'at',
#   'am'],
#  ['that',
#   'moment',
#   'when',
#   'doc',
#   'ockin',
#   "spidey's",
#   'body',
#   'realizes',
#   'that',
#   'spidey',
#   'has',
#   'been',
#   'holding',
#   'back',
#   'in',
#   'their',
#   'fights',
#   'all',
#   'this',
#   'time',
#   'and',
#   'pete',
#   '...'],
#  ['the',
#   'best',
#   'way',
#   'to',
#   'describe',
#   'my',
#   'current',
#   'emotional',
#   'state',
#   'is',
#   'toddler',
#   'in',
#   'a',
#   'wave',
#   'pool',
#   'fine',
#   'for',
#   'the',
#   'most',
#   'part',
#   'but',
#   'gets',
#   'annihilated',
#   'w',
#   '...'],
#  ['nicki',
#   'minaj',
#   'single',
#   'handedly',
#   'annihilated',
#   'the',
#   'male',
#   'species',
#   'the',
#   'day',
#   'this',
#   'dropped'],
#  ['answer',
#   'soooooo',
#   'happy',
#   'i',
#   'did',
#   'not',
#   'renew',
#   'my',
#   'season',
#   'tickets',
#   'i',
#   'would',
#   'have',
#   'lost',
#   'my',
#   'mind',
#   'i',
#   'am',
#   'very',
#   'di',
#   '...'],
#  ['machines',
#   'changed',
#   'music',
#   'pretty',
#   'much',
#   'annihilated',
#   'the',
#   'concept',
#   'of',
#   'a',
#   'live',
#   'band',
#   'playing',
#   'real',
#   'instruments',
#   'however',
#   'machines',
#   'have',
#   'n',
#   '...'],
#  ['lsu',
#   'would',
#   'have',
#   'annihilated',
#   'the',
#   'ohio',
#   'state',
#   'university',
#   'they',
#   'couldnt',
#   'even',
#   'dominate',
#   'wisconsin',
#   '...'],
#  ['should',
#   'mention',
#   'the',
#   'florida',
#   'state',
#   'team',
#   'as',
#   'well',
#   'they',
#   'annihilated',
#   'everybody',
#   'they',
#   'played',
#   'except',
#   'auburn',
#   'who',
#   'they',
#   '...'],
#  ['machines',
#   'changed',
#   'music',
#   'pretty',
#   'much',
#   'annihilated',
#   'the',
#   'concept',
#   'of',
#   'a',
#   'live',
#   'band',
#   'playing',
#   'real',
#   'instruments',
#   'however',
#   'machi',
#   '...'],
#  ["i'm",
#   'getting',
#   'absolutely',
#   'annihilated',
#   'but',
# ...
#  ['blazing',
#   'saddles',
#   'at',
#   'the',
#   'movie',
#   'that',
#   'couldnt',
#   'get',
#   'made',
#   'today',
#   'newsandpolitics',
#   'via'],
#  ['twinkle',
#   'twinkle',
#   'little',
#   'star',
#   'how',
#   'i',
#   'wonder',
#   'what',
#   'you',
#   'are',
#   'up',
#   'above',
#   'the',
#   'world',
#   'so',
#   'high',
#   'like',
#   'a',
#   'diamond',
#   'in',
#   'the',
#   'sky',
#   '...'],
#  ['madeline',
#   'kahn',
#   'as',
#   'lili',
#   'von',
#   'shtupp',
#   'in',
#   'the',
#   'outrageous',
#   'comedy',
#   'classic',
#   'blazing',
#   'saddles',
#   'directed',
#   'by',
#   'mel',
#   'brooks',
#   'lets',
#   'f',
#   '...'],
#  ['announcing',
#   'bengals',
#   'south',
#   'squad',
#   'wr',
#   'group',
#   'edwards',
#   'underrated',
#   'johnson',
#   'enormous',
#   'jennings',
#   'aggressive',
#   'ai',
#   '...'],
#  ['my',
#   'fear',
#   'of',
#   'public',
#   'toilets',
#   'has',
#   'completely',
#   'vanished',
#   'im',
#   'the',
#   'person',
#   'absolutely',
#   'ripping',
#   'the',
#   'train',
#   'station',
#   'toilet',
#   'all',
#   'guns',
#   'blazing'],
#  ['one',
#   'week',
#   'to',
#   'go',
#   'qodebrisbane',
#   'highlights',
#   'incl',
#   'the',
#   'future',
#   'of',
#   'smartcities',
#   'w',
#   'brisbane',
#   'cdo',
#   'quantum',
#   'comput',
#   '...'],
#  ['happy',
#   'birthday',
#   'sir',
#   'you',
#   'are',
#   'indeed',
#   'a',
#   'star',
#   'in',
#   'the',
#   'nursing',
#   'community',
#   'keep',
#   'blazing',
#   'high'],
#  ['once',
#   'again',
#   'i',
#   'am',
#   'loving',
#   'how',
#   'diverse',
#   'and',
#   'body',
#   'positive',
#   'the',
#   'cast',
#   'of',
#   'loveisland',
#   'is',
#   'once',
#   'again',
#   'itv',
#   'bl',
#   '...'],
#  ['eating',
#   'ice',
#   'cream',
#   'underneath',
#   'the',
#   'blazing',
#   'hot',
#   'sun',
#   'is',
#   'just'],
#  ['heres',
#   'an',
#   'interview',
#   'with',
#   'me',
#   'by',
#   'of',
#   'about',
#   'my',
#   'comedy',
#   'horror',
#   'animation',
#   'screening',
#   'at',
#   '...'],
#  ['i',
#   'shot',
#   'one',
#   'of',
#   'two',
#   'colts',
#   'i',
#   'had',
#   'aimed',
#   'at',
#   'him',
#   'the',
#   'one',
#   'in',
#   'my',
#   'left',
#   'hand',
#   'before',
#   'trent',
#   'could',
#   'pull',
#   'the',
#   'trigger',
#   'of',
#   'his',
#   'remington',
#   '...'],
#  ['i',
#   'shot',
#   'one',
#   'of',
#   'two',
#   'colts',
#   'i',
#   'had',
#   'aimed',
#   'at',
#   'him',
#   'the',
#   'one',
#   'in',
#   'my',
#   'left',
#   'hand',
#   'before',
#   'trent',
#   'could',
#   'pull',
#   'the',
#   'trigger',
#   'of',
#   'his',
#   'rem',
#   '...'],
#  ['the',
#   'list',
#   'goes',
#   'on',
#   'all',
#   'these',
#   'folks',
#   'have',
#   'stable',
#   'platforms',
#   'to',
#   'do',
#   'the',
#   '...'],
#  ['i',
#   'swear',
#   'on',
#   'my',
#   'dear',
#   "mother's",
#   'grave--well',
#   'i',
#   'would',
#   'do',
#   'it',
#   'if',
#   'she',
#   'was',
#   'in',
#   'one--that',
#   'i',
#   "wasn't",
#   'goin',
#   "'",
#   'to',
#   'shoot',
#   'you',
#   '"',
#   'trent',
#   '...'],
#  ['hangyul', 'will', 'nae', 'gaseumsoge', 'blazing', 'and', 'then', 'dip'],
#  ['trent',
#   'reached',
#   'his',
#   'right',
#   'hand',
#   'behind',
#   'his',
#   'back',
#   'to',
#   'retrieve',
#   'a',
#   'remington',
#   'he',
#   'had',
#   'stashed',
#   'away',
#   'in',
#   'the',
#   'waistband',
#   'of',
#   'hi',
#   '...'],
#  ['was',
#   'a',
#   'fair',
#   'call',
#   'before',
#   'wc',
#   'should',
#   'have',
#   'done',
#   'it',
#   'at',
#   'the',
#   'wc',
#   'not',
#   'now',
#   'when',
#   'iyer',
#   'has',
#   'been',
#   'in',
#   'blazing',
#   'form',
#   'at'],
#  ['steve',
#   '"',
#   'roustabout',
#   '"',
#   'colston',
#   "didn't",
#   'like',
#   'it',
#   'when',
#   'i',
#   'sent',
#   'his',
#   'brother',
#   'straight',
#   'to',
#   'hell',
#   'neither',
#   'did',
#   'grant',
#   'and',
#   'wesley',
#   'b',
#   '...'],
#  ['blazing',
#   'green',
#   'green',
#   'monday',
#   'on',
#   'telegram',
#   'i',
#   'cant',
#   'thank',
#   'you',
#   'enough',
#   'god',
#   'because',
#   'i',
#   'know',
#   'that',
#   'you',
#   'will',
#   'do',
#   'more',
#   'th',
#   '...'],
#  ['jennie',
#   'looked',
#   'at',
#   'me',
#   'and',
#   'said',
#   '"',
#   'bass',
#   'you',
#   'need',
#   'to',
#   'do',
#   'this',
#   'you',
#   'need',
#   'to',
#   'go',
#   'before',
#   'tecumseh',
#   'kills',
#   'again',
#   '"',
#   'get',
#   'bass',
#   're',
#   '...'],
#  ['excited',
#   'to',
#   'share',
#   'our',
#   'longawaited',
#   'nextjs',
#   'notion',
#   'staticallygenerated',
#   'blog',
#   'example',
#   'with',
#   'the',
#   'same',
#   'tech',
#   'as'],
#  ['"',
#   'i',
#   'got',
#   'me',
#   'a',
#   'deck',
#   'of',
#   'cards',
#   'in',
#   'my',
#   'shirt',
#   'pocket',
#   'if',
#   'you',
#   'boys',
#   'want',
#   'to',
#   'play',
#   'a',
#   'drinkin',
#   "'",
#   'game',
#   'some',
#   'folks',
#   'call',
#   "'",
#   'red',
#   'and',
#   'bla',
#   '...'],
#  ['nowplaying', 'jimpster', 'the', 'blazing', 'water'],
#  ['keep', 'blazing', 't'],
#  ['your',
#   'kindle',
#   'need',
#   'a',
#   'few',
#   'new',
#   'westerns',
#   'in',
#   'it',
#   'fill',
#   'the',
#   'need',
#   'with',
#   'one',
#   'my',
#   'westerns',
#   'like',
#   'bass',
#   'reeves',
#   'blazing',
#   'fury',
#   'now',
#   '...'],
#  ['we',
#   'named',
#   'the',
#   'life',
#   'of',
#   'phantom',
#   'tsukushi',
#   'it',
#   'was',
#   'a',
#   'night',
#   'with',
#   'the',
#   'red',
#   'moon',
#   'blazing',
#   'beautifullyhuan',
#   'noming',
#   'sekainoowari'],
#  ['whats',
#   'with',
#   'all',
#   'these',
#   'angry',
#   'women',
#   'going',
#   'on',
#   'gmb',
#   'with',
#   'all',
#   'guns',
#   'blazing',
#   'meaning',
#   'you',
#   'cant',
#   'take',
#   'them',
#   'or',
#   't',
#   '...'],
#  ['into',
#   'the',
#   'grizzly',
#   'maze',
#   'mobile',
#   'users',
#   'for',
#   'blazing',
#   'fast',
#   'advertising',
#   '...'],
#  ['when',
#   'an',
#   'eagle',
#   'soars',
#   'into',
#   'the',
#   'blazing',
#   'sun',
#   'it',
#   'is',
#   'not',
#   'just',
#   'a',
#   'show',
#   'of',
#   'strength',
#   'but',
#   'because',
#   'he',
#   'truly',
#   'belongs',
#   'at',
#   'the',
#   'top',
#   'you',
#   '...'],
#  ['on',
#   'scorched',
#   'earth',
#   'people',
#   'most',
#   'of',
#   'them',
#   'have',
#   'their',
#   'own',
#   'parallel',
#   'platforms',
#   'when',
#   'they',
#   'enter',
#   'ados',
#   'as',
#   'a',
#   'movement',
#   '...'],
#  ['blazing', 'saddles'],
#  ['our',
#   'od',
#   'team',
#   'is',
#   'certainly',
#   'trail',
#   'blazing',
#   'a',
#   'fabulous',
#   'team',
#   'doing',
#   'great',
#   'things',
#   'this',
#   'will',
#   'be',
#   "someone's",
#   'dream',
#   'job'],
#  ['fun',
#   'fact',
#   'he',
#   'does',
#   'a',
#   'thumbs',
#   'up',
#   'when',
#   'he',
#   'short',
#   'circuits',
#   'to',
#   'let',
#   'people',
#   'know',
#   "he's",
#   'okay',
#   'now',
#   'a',
#   'head',
#   'cannon',
#   'were',
#   '...'],
#  ['why',
#   "can't",
#   'you',
#   'be',
#   'truthful',
#   "it's",
#   'not',
#   'down',
#   'you',
#   'have',
#   'put',
#   'them',
#   'in',
#   'concentration',
#   'camps',
#   'and',
#   'cages',
#   'the',
#   'wall',
#   'has',
#   'nothing',
#   'to',
#   '...'],
#  ['bleeding'],
#  ['hmm', 'scratched', 'my', 'ear', 'now', 'its', 'bleeding'],
#  ['you',
#   'make',
#   'it',
#   'sound',
#   'as',
#   'if',
#   'the',
#   'vegan',
#   'society',
#   'is',
#   'providing',
#   'certi',
#   '...'],
#  ['would',
#   'you',
#   'know',
#   'how',
#   'to',
#   'help',
#   'a',
#   'victim',
#   'of',
#   'knife',
#   'crime',
#   'download',
#   'our',
#   'new',
#   'app',
#   'to',
#   'learn',
#   'lifesaving',
#   'bleeding',
#   'control',
#   'technique',
#   '...'],
#  ['playing',
#   'mhw',
#   'with',
#   'friends',
#   'friend',
#   'jerky',
#   'curse',
#   'bleeding',
#   'other',
#   'friend',
#   'yeah',
#   'me',
#   'i',
#   'wish'],
#  ['"',
#   'doctor',
#   'help',
#   'me',
#   "i've",
#   'been',
#   'wounded',
#   'and',
#   "i'm",
#   'bleeding',
#   'to',
#   'death',
#   'please',
#   'stem',
#   'the',
#   'bleeding',
#   'get',
#   'me',
#   'a',
#   'bandage',
#   '"',
#   '"',
#   'ah',
#   'but',
#   'there',
#   '...'],
#  ['the',
#   'bleeding',
#   'hearts',
#   'and',
#   'artists',
#   'let',
#   'him',
#   'get',
#   'away',
#   'with',
#   'murder',
#   'let',
#   'me',
#   'hammer',
#   'him',
#   'today',
#   'the',
#   'trial'],
#  ['i',
#   'ask',
#   'for',
#   'prayer',
#   'for',
#   'my',
#   'daughter',
#   'please',
#   'i',
#   'took',
#   'her',
#   'in',
#   'thinking',
#   'she',
#   'had',
#   'the',
#   'flu',
#   'and',
#   'she',
#   'is',
#   'in',
#   'intensive',
#   'care',
#   'with',
#   'an',
#   'a',
#   '...'],
#  ['has',
#   'a',
#   'chance',
#   'to',
#   'stop',
#   'this',
#   'bleeding',
#   'at',
#   'the',
#   'debate',
#   'tomorrow',
#   'night',
#   'we',
#   'will',
#   'see',
#   'if',
#   'she',
#   'does',
#   'the',
#   'right',
#   'thing'],
#  ['imagine',
#   'supporting',
#   'biden',
#   'fucking',
#   'biden',
#   'the',
#   'little',
#   'girl',
#   '...'],
#  ['sometimes',
#   'i',
#   'want',
#   'dio',
#   'to',
#   'fucking',
#   'eviscerate',
#   'me',
#   'and',
#   'then',
#   'make',
#   'sweet',
#   'sweet',
#   'love',
#   'to',
#   'my',
#   'open',
#   'festering',
#   'wounds',
#   'as',
#   'i',
#   'lay',
#   'b',
#   '...'],
#  ['president',
#   'of',
#   'united',
#   'states',
#   'makes',
#   'our',
#   'country',
#   'a',
#   'living',
#   'fking',
#   'hell',
#   'i',
#   'try',
#   'stay',
#   'positive',
#   'about',
#   'the',
#   'election',
#   'but',
#   'her',
#   '...'],
#  ['ghanaian',
#   'women',
#   'would',
#   'stab',
#   'you',
#   'in',
#   'the',
#   'back',
#   'then',
#   'ask',
#   'you',
#   'why',
#   "you're",
#   'bleeding'],
#  ['live',
#   'cervical',
#   'cancer',
#   'bleeding',
#   'and',
#   'pain',
#   'after',
#   'sex',
#   'can',
#   'be',
#   'symptoms',
#   'of',
#   'disease',
#   'dr',
#   'kwaku',
#   'asah',
#   'opoku',
#   'obstetric',
#   '...'],
#  ['iran',
#   'video',
#   'shows',
#   'woman',
#   'protester',
#   'shot',
#   'bleeding',
#   'on',
#   'street',
#   'via'],
#  ['stop',
#   'ur',
#   'bleeding',
#   'but',
#   'nothing',
#   'ever',
#   'stops',
#   'ur',
#   'leaving'],
#  ['live',
#   'cervical',
#   'cancer',
#   'bleeding',
#   'after',
#   'menopause',
#   'is',
#   'a',
#   'sign',
#   'of',
#   'disease',
#   'dr',
#   'kwaku',
#   'ansah',
#   'opoku',
#   'obstetrician',
#   'amp',
#   'g',
#   '...'],
#  ['mum',
#   'dying',
#   'of',
#   'cervical',
#   'cancer',
#   'was',
#   'denied',
#   'smear',
#   'test',
#   'despite',
#   'bleeding',
#   'after',
#   'sex'],
#  ['freedom',
#   'of',
#   'movement',
#   'bleeding',
#   'central',
#   'and',
#   'souther',
#   'europe',
#   'dry'],
#  ['u', 'tweet', 'this', 'as', 'im', 'listening', 'to', 'bleeding', 'love'],
#  ['well',
#   'done',
#   'boris',
#   'a',
#   'statement',
#   'of',
#   'the',
#   'bleeding',
#   'obvious',
#   'bbc',
#   'news',
#   'harry',
#   'and',
#   'meghan',
#   'royal',
#   'family',
#   'will',
#   '...'],
#  ['bleeding',
#   'heart',
#   'music',
#   'video',
#   'coming',
#   'very',
#   'soon',
#   'vicscover',
#   'bleedingheart',
#   'musicvideo',
#   'rocknroll',
#   'gothrock',
#   'cali',
#   '...'],
#  ['bleeding', 'madras', 'be', 'that'],
#  ['the',
#   'reference',
#   'to',
#   'bleedingheart',
#   'liberals',
#   'who',
#   'are',
#   'too',
#   'influenced',
#   'by',
#   'the',
#   'ideology',
#   'ofrousseau',
#   'made',
#   'me',
#   'snort',
#   'with',
#   '...'],
#  ['glen',
#   'says',
#   'the',
#   'bleeding',
#   'obvious',
#   'im',
#   'so',
#   'over',
#   'being',
#   'labelled',
#   'negative',
#   'pessimistic',
#   'or',
#   'a',
#   'doomer',
#   'for',
#   'telling',
#   'the',
#   'godd',
#   '...'],
#  ['post',
#   'malone',
#   'hollywoods',
#   'bleeding',
#   'slowed',
#   'to',
#   'perfection',
#   'via'],
#  ['icymi',
#   '"',
#   'silence',
#   'surrounds',
#   'revelations',
#   'of',
#   "mueller's",
#   'collaboration',
#   'with',
#   'cia',
#   'torture',
#   'program',
#   '"',
#   'my',
#   'new',
#   'article',
#   'on',
#   'guantanamo',
#   '...'],
#  ["i'm",
#   'confused',
#   'about',
#   'what',
#   'her',
#   'actual',
#   'position',
#   'is',
#   'if',
#   "she's",
#   'criticizing',
#   'the',
#   'idea',
#   'of',
#   'putting',
#   'tampon',
#   'machines',
#   'in',
#   'the',
#   '...'],
#  ['people',
#   'are',
#   'going',
#   'bankrupt',
#   'over',
#   'medical',
#   'debt',
#   'k',
#   'a',
#   'year',
#   'minus',
#   'the',
#   'vat',
#   'wont',
#   'put',
#   'a',
#   'dent',
#   'in',
#   'that',
#   'let',
#   '...'],
#  ['my', 'nose', 'is', 'bleeding', 'too', 'wtf'],
#  ['jojo', 'or', 'the', 'outcome', 'of', 'that', 'picture'],
#  ['scmp',
#   'ocean',
#   'park',
#   'bailout',
#   'plan',
#   'by',
#   'hong',
#   'kong',
#   'government',
#   'will',
#   'help',
#   'fund',
#   "attraction's",
#   'revival',
#   'not',
#   'just',
#   "'",
#   'stop',
#   'the',
#   'bleeding',
#   "'",
#   '...'],
#  ['but',
#   'at',
#   'anfield',
#   'we',
#   'actually',
#   'found',
#   'out',
#   'that',
#   'the',
#   'roma',
#   'scars',
#   'were',
#   'just',
#   'lightly',
#   'bandaged',
#   'and',
#   'they',
#   'got',
#   'opened',
#   'up',
#   'again',
#   'to',
#   '...'],
#  ['thank',
#   'you',
#   'i',
#   "don't",
#   'think',
#   "it's",
#   'normal',
#   'i',
#   'have',
#   'had',
#   'them',
#   'before',
#   'but',
#   'they',
#   "haven't",
#   'been',
#   'like',
#   'this',
#   'they',
#   '...'],
#  ['for',
#   'the',
#   'th',
#   'time',
#   'a',
#   'bandage',
#   'around',
#   'the',
#   'head',
#   'does',
#   'not',
#   'mean',
#   'that',
#   'the',
#   'whole',
#   'skull',
#   'is',
#   'broken',
#   'the',
#   'bandage',
#   'goes',
#   'aroun',
#   '...'],
#  ['nevermind', 'my', 'nose', 'started', 'bleeding'],
#  ['imagine',
#   'being',
#   'shot',
#   'by',
#   'your',
#   'own',
#   'government',
#   'because',
#   'you',
#   'want',
#   'freedom',
#   'its',
#   'hard',
#   'to',
#   'imagine',
#   'right',
#   'i',
#   'mean',
#   'were',
#   'america',
#   '...'],
#  ['i',
#   'forgot',
#   'my',
#   'lip',
#   'balm',
#   'and',
#   'now',
#   "i'm",
#   'holding',
#   'a',
#   'sleeping',
#   'baby',
#   'and',
#   'my',
#   'lips',
#   'are',
#   'dry',
#   'and',
#   'cracked',
#   'and',
#   'bleeding'],
#  ['very',
#   'sad',
#   'and',
#   'sorry',
#   'state',
#   'of',
#   'indian',
#   'economy',
#   'government',
#   'priority',
#   'is',
#   'to',
#   'see',
#   'saffron',
#   'color',
#   'on',
#   'indian',
#   'mapbut',
#   'not',
#   'b',
#   '...'],
#  ['intravenous',
#   'oxytocin',
#   'reduces',
#   'severe',
#   'bleeding',
#   'after',
#   'vaginal',
#   'delivery',
#   'nihr',
#   'signal',
#   '...'],
#  ['it',
#   'wont',
#   'taste',
#   'the',
#   'same',
#   'and',
#   'like',
#   "i'd",
#   'diewhich',
#   'is',
#   'fine',
#   'but',
#   "likei'd",
#   'rather',
#   'not',
#   'die',
#   '...'],
#  ['halfway',
#   'into',
#   'january',
#   'how',
#   'are',
#   'your',
#   'finances',
#   'looking',
#   'if',
#   'your',
#   'pocket',
#   'is',
#   'still',
#   'bleeding',
#   'this',
#   'is',
#   'the',
#   'time',
#   'to',
#   'give',
#   'our',
#   'fina',
#   '...'],
#  ['to',
#   'the',
#   'parents',
#   'of',
#   'the',
#   'child',
#   'screaming',
#   'in',
#   'the',
#   'airport',
#   'i',
#   'understand',
#   'children',
#   'are',
#   'alot',
#   'to',
#   'handle',
#   'but',
#   'my',
#   'ears',
#   'are',
#   'bleeding'],
#  ['oh',
#   'my',
#   'god',
#   'my',
#   'fucking',
#   'eyes',
#   'and',
#   'ears',
#   'are',
#   'literally',
#   'bleeding',
#   'after',
#   'watching',
#   'this'],
#  ['my', 'cat', 'just', 'went', 'crazy', 'to', 'me', "i'm", 'bleeding'],
#  ['we',
#   'saw',
#   'more',
#   'reports',
#   'of',
#   'women',
#   'who',
#   'had',
#   'increased',
#   'menstruational',
#   'bleeding',
#   '...'],
#  ['floral',
#   'notes',
#   'of',
#   'bleeding',
#   'heart',
#   'flower',
#   'and',
#   'fresh',
#   'peony',
#   'petals',
#   'will',
#   'have',
#   'you',
#   'lusting',
#   'over',
#   'madlove',
#   'perfumeholics'],
#  ['i',
#   'wonder',
#   "who's",
#   'rick',
#   'or',
#   'ricky',
#   'because',
#   'that',
#   'dude',
#   'is',
#   'bleeding'],
#  ['hopefully',
#   'minding',
#   'their',
#   'own',
#   'business',
#   'as',
#   'all',
#   'republicans',
#   'should',
#   'be',
#   'unless',
#   'you',
#   'are',
#   'on',
#   'the',
#   'streets',
#   'with',
#   'the',
#   'iranian',
#   'prote',
#   '...'],
#  ['mcr',
#   'stans',
#   'are',
#   'those',
#   'kids',
#   'in',
#   'primary',
#   'school',
#   'that',
#   'if',
#   'they',
#   'were',
#   'bleeding',
#   'theyd',
#   'just',
#   'put',
#   'the',
#   'cut',
#   'in',
#   'their',
#   'mouth',
#   'to',
#   'stop',
#   'the',
#   '...'],
#  ['so',
#   'much',
#   'history',
#   'submerged',
#   'in',
#   'mucky',
#   'details',
#   'no',
#   'clarity',
#   'on',
#   'who',
#   'why',
#   'and',
#   'when',
#   'so',
#   'much',
#   'deaths',
#   'and',
#   'bleeding',
#   'and',
#   'yet',
#   'v',
#   '...'],
#  ['i', 'kinda', 'want', 'to', 'watch', 'it'],
#  ['ghanaian',
#   'women',
#   'would',
#   'stab',
#   'you',
#   'in',
#   'the',
#   'back',
#   'then',
#   'ask',
#   'you',
#   'why',
#   "you're",
#   'bleeding'],
#  ['in',
#   'the',
#   'context',
#   'of',
#   'major',
#   'bleeding',
#   'a',
#   'cat',
#   'is',
#   'a',
#   'combat',
#   'application',
#   'tourniquet',
#   'so',
#   'saying',
#   '"',
#   'cat',
#   'tourniquet',
#   '"',
#   'is',
#   'an',
#   'example',
#   'of',
#   '"',
#   'redundan',
#   '...'],
#  ['its',
#   'weird',
#   'how',
#   'ppl',
#   'w',
#   'vaginas',
#   'literally',
#   'spent',
#   'days',
#   'bleeding',
#   'and',
#   'having',
#   'a',
#   'severe',
#   'cramps',
#   'nausea',
#   'headaches',
#   'and',
#   'muscle',
#   'ache',
#   '...'],
#  ['mum',
#   'dying',
#   'of',
#   'cervical',
#   'cancer',
#   'was',
#   'denied',
#   'smear',
#   'test',
#   'despite',
#   'bleeding',
#   'after',
#   'sex',
#   'mirror',
#   'online'],
#  ['seven',
#   'headed',
#   'snake',
#   'what',
#   'u',
#   'call',
#   'that',
#   'bleeding',
#   'like',
#   'an',
#   'open',
#   'scar'],
#  ...]

# %% [markdown]
# ## EDA

# %%
# Count all words from all tweets.
word_counts = Counter(x for xs in mylist_tokenized for x in xs) # The snippet of code I found online for this used set(xs) at the end.
top_word_counts = word_counts.most_common(20)

# %%
# Sort the tuples by the second value (frequency).
top_word_counts.sort(key=lambda a: a[1])
top_word_counts
# Out:
# [('at', 938),
#  ('my', 948),
#  ('was', 963),
#  ('are', 1051),
#  ('with', 1102),
#  ('it', 1136),
#  ('this', 1345),
#  ('that', 1430),
#  ('you', 1464),
#  ('on', 1494),
#  ('for', 1698),
#  ('i', 2254),
#  ('is', 2314),
#  ('and', 3149),
#  ('in', 3394),
#  ('of', 3610),
#  ('a', 4253),
#  ('to', 4331),
#  ('...', 7076),
#  ('the', 7639)]

# %%
# Extract information from tuples and put into seperate lists.
top_words=[]

for i in range(20):
    word = top_word_counts[i][0]
    top_words.append(word)

top_words_frequency=[]

for i in range(20):
    count = top_word_counts[i][1]
    top_words_frequency.append(count)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# Plot the top 20 words with their frequencies.
plt.style.use('seaborn-notebook')
plt.figure(figsize=[12,8])
plt.barh(top_words, top_words_frequency)
plt.title("Top 20 Common Words Across Disaster Tweets")
plt.xlabel("Counts")
plt.ylabel("Words")
# Out:
# Text(0, 0.5, 'Words')

# %%
# Create a list of tweet word counts.
tweet_lengths=[]

for i in range(len(mylist_tokenized)):
    length = len(mylist_tokenized[i])
    tweet_lengths.append(length)

# %%
# Plot a histogram of tweet word counts.
plt.figure(figsize=[12,8])
plt.hist(tweet_lengths)
plt.title("Amount of Words in Disaster Tweets")
plt.xlabel("Number of Words")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
# Plot a word cloud of words across all tweets.
word_cloud_text = " ".join(i for i in mylist)

wordcloud = WordCloud(width = 1400, height = 1000,
                background_color ='white',
                min_font_size = 10).generate(word_cloud_text) # ignores built in stopwords list by default

plt.figure(figsize=[12,12])
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# Come back to later after EDA:

# %% [markdown]
# ## Stop Words?

# %%
# Will want to use b/c top words are all common stop words.

# %% [markdown]
# ## Lemmatize

# %% [markdown]
# ## POS Tagging? Named Entity Recognition?
