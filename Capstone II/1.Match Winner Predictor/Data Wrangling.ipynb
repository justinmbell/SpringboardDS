# %% [markdown]
# # Capstone 2: Data Wrangling (Match Winner Predictor)

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### Players File

# %%
players_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/players.xlsx')
players_df.head()
# Out:
#         date player_name           team       opponent        country  \
# 0 2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1 2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2 2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3 2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4 2020-02-26         NAF         Liquid  Evil Geniuses         Canada
#
#    player_id  match_id  event_id         event_name  best_of  ...  \
# 0       9136   2339385      4901  IEM Katowice 2020        3  ...
# 1      11219   2339385      4901  IEM Katowice 2020        3  ...
# 2       8738   2339385      4901  IEM Katowice 2020        3  ...
# 3      10671   2339385      4901  IEM Katowice 2020        3  ...
# 4       8520   2339385      4901  IEM Katowice 2020        3  ...
#
#   m3_kddiff_ct m3_adr_ct m3_kast_ct  m3_rating_ct  m3_kills_t  m3_deaths_t  \
# ...

# %%
players_df.shape
# Out:
# (383317, 101)

# %%
players_df.dtypes
# Out:
# date           datetime64[ns]
# player_name            object
# team                   object
# opponent               object
# country                object
#                     ...
# m3_deaths_t           float64
# m3_kddiff_t           float64
# m3_adr_t              float64
# m3_kast_t             float64
# m3_rating_t           float64
# Length: 101, dtype: object

# %% [markdown]
# ### Results File

# %%
results_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/results.xlsx')
results_df.head()
# Out:
#         date               team_1          team_2     _map  result_1  \
# 0 2020-03-18              Recon 5         TeamOne    Dust2         0
# 1 2020-03-18              Recon 5         TeamOne  Inferno        13
# 2 2020-03-18  New England Whalers        Station7  Inferno        12
# 3 2020-03-18              Rugratz  Bad News Bears  Inferno         7
# 4 2020-03-18              Rugratz  Bad News Bears  Vertigo         8
#
#    result_2  map_winner  starting_ct  ct_1  t_2  t_1  ct_2  event_id  \
# 0        16           2            2     0    1    0    15      5151
# 1        16           2            2     8    6    5    10      5151
# 2        16           2            1     9    6    3    10      5243
# 3        16           2            2     0    8    7     8      5151
# 4        16           2            2     4    5    4    11      5151
#
#    match_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# 0   2340454      62      63           0           2             2
# ...

# %%
results_df.shape
# Out:
# (45773, 19)

# %%
results_df.dtypes
# Out:
# date            datetime64[ns]
# team_1                  object
# team_2                  object
# _map                    object
# result_1                 int64
# result_2                 int64
# map_winner               int64
# starting_ct              int64
# ct_1                     int64
# t_2                      int64
# t_1                      int64
# ct_2                     int64
# event_id                 int64
# match_id                 int64
# rank_1                   int64
# rank_2                   int64
# map_wins_1               int64
# map_wins_2               int64
# match_winner             int64
# dtype: object

# %% [markdown]
# ## Merging Dataframes and Creating New Columns

# %%
# Create a new column 'winning_team' that has the team name that won the match rather than 1 or 2.
mw_list = []
for index, row in results_df.iterrows():
    value = row['match_winner']
    if value == 1:
        mw_list.append(row['team_1'])
    else:
        mw_list.append(row['team_2'])
results_df['winning_team'] = mw_list

# %%
# Assure that the new 'winning_team' column has the right values.
results_df.tail()
# Out:
#             date team_1      team_2         _map  result_1  result_2  \
# 45768 2015-11-05     G2  E-frag.net      Inferno        13        16
# 45769 2015-11-05     G2  E-frag.net        Dust2        16        13
# 45770 2015-11-04    CLG      Liquid      Inferno        16        12
# 45771 2015-11-03    NiP    Dignitas        Train        16         4
# 45772 2015-11-03    NiP        Envy  Cobblestone        16         9
#
#        map_winner  starting_ct  ct_1  t_2  t_1  ct_2  event_id  match_id  \
# 45768           2            1     8    7    5     9      1970   2299059
# 45769           1            1    10    5    6     8      1970   2299059
# 45770           1            1     7    8    9     4      1934   2299011
# 45771           1            2     4    1   12     3      1934   2299001
# 45772           1            2     4    6   12     3      1934   2299003
#
#        rank_1  rank_2  map_wins_1  map_wins_2  match_winner winning_team
# ...

# %%
# Drop all rows with duplicated match_ids (we only need one map in the match to have the winning_team value b/c it's the same across all maps).
results_df.drop_duplicates(subset = 'match_id', inplace = True, ignore_index = True)

# %%
# Assure that the new dataframe has no rows with duplicate match_ids.
results_df['match_id'].is_unique
# Out:
# True

# %%
# Drop all columns except match_id and winning_team.
results_df.drop(['date', 'team_1', 'team_2', '_map', 'result_1', 'result_2', 'map_winner', 'starting_ct', 'ct_1', 't_2', 't_1', 'ct_2', 'event_id', 'rank_1', 'rank_2', 'map_wins_1', 'map_wins_2', 'match_winner'], axis=1, inplace=True)

# %%
# Assure that the new dataframe has only our two columns of interest in preparation for a merge.
results_df.head()
# Out:
#    match_id    winning_team
# 0   2340454         TeamOne
# 1   2340461        Station7
# 2   2340453  Bad News Bears
# 3   2340456        Endpoint
# 4   2340455          Espada

# %%
# Merge the new results dataframe with the players dataframe on match_id (must do inner join so that we have no null values in the winning_team column).
df = pd.merge(players_df, results_df, how='inner', on='match_id')

# %%
# Assure that the new winning_team column has been correctly merged.
df.head()
# Out:
#         date player_name           team       opponent        country  \
# 0 2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1 2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2 2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3 2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4 2020-02-26         NAF         Liquid  Evil Geniuses         Canada
#
#    player_id  match_id  event_id         event_name  best_of  ... m3_adr_ct  \
# 0       9136   2339385      4901  IEM Katowice 2020        3  ...      72.5
# 1      11219   2339385      4901  IEM Katowice 2020        3  ...      79.5
# 2       8738   2339385      4901  IEM Katowice 2020        3  ...      81.5
# 3      10671   2339385      4901  IEM Katowice 2020        3  ...      67.2
# 4       8520   2339385      4901  IEM Katowice 2020        3  ...      72.9
#
#   m3_kast_ct m3_rating_ct  m3_kills_t  m3_deaths_t  m3_kddiff_t  m3_adr_t  \
# ...

# %%
# Create a new column 'match_outcome' that has a value of Win or Loss based on whether the winning_team and the team they play for match.
o_list = []
for index, row in df.iterrows():
    winner = row['winning_team']
    team = row['team']
    if winner == team:
        o_list.append('Win')
    else:
        o_list.append('Loss')
df['match_outcome'] = o_list

# %%
# Assure that the new 'match_outcome' column has the right values.
df.head()
# Out:
#         date player_name           team       opponent        country  \
# 0 2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1 2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2 2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3 2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4 2020-02-26         NAF         Liquid  Evil Geniuses         Canada
#
#    player_id  match_id  event_id         event_name  best_of  ... m3_kast_ct  \
# 0       9136   2339385      4901  IEM Katowice 2020        3  ...       80.0
# 1      11219   2339385      4901  IEM Katowice 2020        3  ...       53.3
# 2       8738   2339385      4901  IEM Katowice 2020        3  ...       63.6
# 3      10671   2339385      4901  IEM Katowice 2020        3  ...       66.7
# 4       8520   2339385      4901  IEM Katowice 2020        3  ...       81.8
#
#   m3_rating_ct m3_kills_t  m3_deaths_t  m3_kddiff_t  m3_adr_t  m3_kast_t  \
# ...

# %% [markdown]
# ## Subsetting the best_of Column

# %%
# Frequency of bo1, bo2, bo3, and bo5 matches in our data.
df['best_of'].value_counts()
# Out:
# 1    133364
# 3    119630
# 2     10992
# 5      1399
# Name: best_of, dtype: int64

# %%
# Drop best of 2 match rows.
df_filtered = df[df['best_of'] != 2]

# %%
# Drop best of 3 match rows.
df_filtered = df_filtered[df_filtered['best_of'] != 3]

# %%
# Drop best of 5 match rows.
df_bo1 = df_filtered[df_filtered['best_of'] != 5]

# %%
# Assure that bo2, bo3, and bo5 matches are gone.
df_bo1['best_of'].value_counts()
# Out:
# 1    133364
# Name: best_of, dtype: int64

# %% [markdown]
# ## Renaming and Dropping Columns

# %%
# View all columns in the df.
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df_bo1.head()
# Out:
#          date player_name           team       opponent        country  \
# 60 2020-02-27    Andersin  Thunder Logic       Station7  United States
# 61 2020-02-27    FrostayK       Station7  Thunder Logic  United States
# 62 2020-02-27   Inseaniac  Thunder Logic       Station7         Canada
# 63 2020-02-27      JonahP       Station7  Thunder Logic         Canada
# 64 2020-02-27       PureR  Thunder Logic       Station7  United States
#
#     player_id  match_id  event_id                        event_name  best_of  \
# 60      14038   2339816      5151  ESEA MDL Season 33 North America        1
# 61      12090   2339816      5151  ESEA MDL Season 33 North America        1
# 62      18623   2339816      5151  ESEA MDL Season 33 North America        1
# 63      11445   2339816      5151  ESEA MDL Season 33 North America        1
# 64      10622   2339816      5151  ESEA MDL Season 33 North America        1
#
# ...

# %%
# Drop columns pertaining to map 2 and map 3.
df_bo1 = df_bo1.drop(['map_2', 'map_3', 'm2_kills', 'm2_assists', 'm2_deaths', 'm2_hs', 'm2_flash_assists', 'm2_kast', 'm2_kddiff', 'm2_adr', 'm2_fkdiff', 'm2_rating', 'm3_kills', 'm3_assists', 'm3_deaths', 'm3_hs', 'm3_flash_assists', 'm3_kast', 'm3_kddiff', 'm3_adr', 'm3_fkdiff', 'm3_rating', 'm2_kills_ct', 'm2_deaths_ct', 'm2_kddiff_ct', 'm2_adr_ct', 'm2_kast_ct', 'm2_rating_ct', 'm2_kills_t', 'm2_deaths_t', 'm2_kddiff_t', 'm2_adr_t', 'm2_kast_t', 'm2_rating_t', 'm3_kills_ct', 'm3_deaths_ct', 'm3_kddiff_ct', 'm3_adr_ct', 'm3_kast_ct', 'm3_rating_ct', 'm3_kills_t', 'm3_deaths_t', 'm3_kddiff_t', 'm3_adr_t', 'm3_kast_t', 'm3_rating_t'], axis=1)

# %%
# Assure that the drop was done correctly.
df_bo1.head()
# Out:
#          date player_name           team       opponent        country  \
# 60 2020-02-27    Andersin  Thunder Logic       Station7  United States
# 61 2020-02-27    FrostayK       Station7  Thunder Logic  United States
# 62 2020-02-27   Inseaniac  Thunder Logic       Station7         Canada
# 63 2020-02-27      JonahP       Station7  Thunder Logic         Canada
# 64 2020-02-27       PureR  Thunder Logic       Station7  United States
#
#     player_id  match_id  event_id                        event_name  best_of  \
# 60      14038   2339816      5151  ESEA MDL Season 33 North America        1
# 61      12090   2339816      5151  ESEA MDL Season 33 North America        1
# 62      18623   2339816      5151  ESEA MDL Season 33 North America        1
# 63      11445   2339816      5151  ESEA MDL Season 33 North America        1
# 64      10622   2339816      5151  ESEA MDL Season 33 North America        1
#
# ...

# %%
# Drop other columns which store the same information as another (ex. kills = m1_kills), along with a few others.
df_bo1 = df_bo1.drop(['m1_kills', 'm1_assists', 'm1_deaths', 'm1_hs', 'm1_flash_assists', 'm1_kast', 'm1_kddiff', 'm1_adr', 'm1_fkdiff', 'm1_rating', 'm1_kills_ct', 'm1_deaths_ct', 'm1_kddiff_ct', 'm1_adr_ct', 'm1_kast_ct', 'm1_rating_ct', 'm1_kills_t', 'm1_deaths_t', 'm1_kddiff_t', 'm1_adr_t', 'm1_kast_t', 'm1_rating_t', 'winning_team', 'best_of'], axis = 1)

# %%
# Rename columns.
df_bo1.rename(columns = {'map_1':'map'}, inplace = True)

# %%
# Assure that all of the changes went through.
df_bo1.head()
# Out:
#          date player_name           team       opponent        country  \
# 60 2020-02-27    Andersin  Thunder Logic       Station7  United States
# 61 2020-02-27    FrostayK       Station7  Thunder Logic  United States
# 62 2020-02-27   Inseaniac  Thunder Logic       Station7         Canada
# 63 2020-02-27      JonahP       Station7  Thunder Logic         Canada
# 64 2020-02-27       PureR  Thunder Logic       Station7  United States
#
#     player_id  match_id  event_id                        event_name       map  \
# 60      14038   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 61      12090   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 62      18623   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 63      11445   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 64      10622   2339816      5151  ESEA MDL Season 33 North America  Overpass
#
# ...

# %% [markdown]
# ## Exploring Column Unique Value Counts

# %%
# Count of unique values by column.
df_bo1.nunique()
# Out:
# date              1193
# player_name       3685
# team              1102
# opponent          1102
# country             82
# player_id         3719
# match_id         13337
# event_id           889
# event_name         889
# map                  9
# kills               62
# assists             21
# deaths              57
# hs                  36
# flash_assists       14
# kast               338
# kddiff              56
# adr               1398
# fkdiff              24
# rating             271
# kills_ct            37
# deaths_ct           28
# kddiff_ct           44
# adr_ct            1946
# kast_ct            186
# rating_ct          403
# kills_t             37
# deaths_t            35
# kddiff_t            44
# adr_t             1944
# kast_t             201
# rating_t           432
# match_outcome        2
# dtype: int64

# %% [markdown]
# The amount of unique values in each columns are about as expected at first glance.

# %% [markdown]
# ## Data Types and Range of Values

# %%
df_bo1.dtypes
# Out:
# date             datetime64[ns]
# player_name              object
# team                     object
# opponent                 object
# country                  object
# player_id                 int64
# match_id                  int64
# event_id                  int64
# event_name               object
# map                      object
# kills                     int64
# assists                   int64
# deaths                    int64
# hs                        int64
# flash_assists           float64
# kast                    float64
# kddiff                    int64
# adr                     float64
# fkdiff                    int64
# rating                  float64
# kills_ct                float64
# deaths_ct               float64
# kddiff_ct               float64
# adr_ct                  float64
# kast_ct                 float64
# rating_ct               float64
# kills_t                 float64
# deaths_t                float64
# kddiff_t                float64
# ...

# %%
# Check to see if the flash_assists column is ever not an integer.
df_bo1['flash_assists'].value_counts()
# Out:
# 0.0     45454
# 1.0     26622
# 2.0     13821
# 3.0      6604
# 4.0      3023
# 5.0      1317
# 6.0       547
# 7.0       246
# 8.0        95
# 9.0        41
# 10.0       21
# 13.0        2
# 12.0        2
# 11.0        1
# Name: flash_assists, dtype: int64

# %%
# Check to see if the kills_ct column is ever not an integer.
df_bo1['kills_ct'].value_counts()
# Out:
# 9.0     11148
# 8.0     11028
# 10.0    10718
# 7.0     10441
# 11.0     9752
# 6.0      9568
# 12.0     8744
# 5.0      8029
# 13.0     7319
# 4.0      6850
# 14.0     6121
# 3.0      5379
# 15.0     4763
# 2.0      4180
# 16.0     3649
# 1.0      2866
# 17.0     2768
# 18.0     2034
# 19.0     1375
# 0.0      1001
# 20.0      968
# 21.0      593
# 22.0      433
# 23.0      263
# 24.0      194
# 25.0      110
# 26.0       66
# 27.0       51
# 28.0       43
# 29.0       18
# 30.0       14
# 32.0        8
# 31.0        3
# 33.0        2
# 37.0        1
# 41.0        1
# 34.0        1
# Name: kills_ct, dtype: int64

# %%
# Check to see if the kills_ct column is ever not an integer.
df_bo1['deaths_ct'].value_counts()
# Out:
# 9.0     14812
# 8.0     14505
# 10.0    14209
# 7.0     13250
# 11.0    12332
# 6.0     11140
# 12.0    10034
# 5.0      8781
# 13.0     7051
# 4.0      6829
# 3.0      4953
# 14.0     3949
# 2.0      3268
# 1.0      1727
# 15.0     1649
# 16.0      628
# 0.0       623
# 17.0      310
# 18.0      184
# 19.0      124
# 20.0       53
# 21.0       32
# 22.0       25
# 23.0       12
# 25.0       12
# 24.0        6
# 27.0        3
# 28.0        1
# Name: deaths_ct, dtype: int64

# %%
# Check to see if the kills_ct column is ever not an integer.
df_bo1['kddiff_ct'].value_counts()
# Out:
# -1.0     10751
#  0.0     10647
#  1.0     10176
# -2.0     10041
#  2.0      9324
# -3.0      9020
#  3.0      8544
#  4.0      7482
# -4.0      7406
#  5.0      6603
# -5.0      5779
#  6.0      5443
#  7.0      4514
# -6.0      4296
#  8.0      3384
# -7.0      2959
#  9.0      2772
#  10.0     2119
# -8.0      1917
#  11.0     1515
# -9.0      1152
#  12.0     1100
#  13.0      728
# -10.0      699
#  14.0      551
#  15.0      376
# -11.0      318
#  16.0      238
# -12.0      167
#  17.0      149
#  18.0      119
#  19.0       59
# -13.0       49
#  20.0       45
#  21.0       27
#  22.0       10
# -14.0        8
#  23.0        4
#  24.0        4
# -16.0        2
# -15.0        2
#  26.0        1
# -20.0        1
#  25.0        1
# Name: kddiff_ct, dtype: int64

# %% [markdown]
# We'll want to convert these columns for both CT and T to have values that are integers once we deal with the null values later on.

# %%
df_bo1.describe()
# Out:
#            player_id      match_id       event_id         kills  \
# count  133364.000000  1.333640e+05  133364.000000  133364.00000
# mean     9004.208872  2.319425e+06    3398.700489      17.64309
# std      4184.916513  1.048589e+04     789.879418       6.32929
# min         2.000000  2.299001e+06    1615.000000       0.00000
# 25%      7429.000000  2.310948e+06    2729.000000      13.00000
# 50%      9078.000000  2.319395e+06    3374.000000      17.00000
# 75%     11586.000000  2.327738e+06    3965.000000      22.00000
# max     20007.000000  2.339828e+06    5224.000000      75.00000
#
#              assists         deaths             hs  flash_assists  \
# count  133364.000000  133364.000000  133364.000000   97796.000000
# mean        4.109137      17.674132       7.984119       1.013917
# std         2.444149       4.811923       3.879718       1.303215
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# All column value ranges make logical sense. Death columns can have values over 15 because of overtime matches.

# %% [markdown]
# ## Checking for Duplicates

# %%
# Check for unwanted duplicate rows (match_id and player_name).
df_bo1.duplicated(subset=['match_id', 'player_name']).mean()
# Out:
# 0.0

# %% [markdown]
# ## Exploring and Dealing with Null Values

# %%
# Check to see which columns, if any, have null values and how many there are.
df_bo1_missing = pd.concat([df_bo1.isnull().sum(), 100 * df_bo1.isnull().mean()], axis=1)
df_bo1_missing.columns=['count', '%']
df_bo1_missing.sort_values(by= ['count', '%'], ascending = False)
# Out:
#                count          %
# flash_assists  35568  26.669866
# kills_ct        2862   2.146006
# deaths_ct       2862   2.146006
# kddiff_ct       2862   2.146006
# adr_ct          2862   2.146006
# kast_ct         2862   2.146006
# rating_ct       2862   2.146006
# kills_t         2862   2.146006
# deaths_t        2862   2.146006
# kddiff_t        2862   2.146006
# adr_t           2862   2.146006
# kast_t          2862   2.146006
# rating_t        2862   2.146006
# adr             1564   1.172730
# kast            1559   1.168981
# date               0   0.000000
# player_name        0   0.000000
# team               0   0.000000
# opponent           0   0.000000
# country            0   0.000000
# player_id          0   0.000000
# match_id           0   0.000000
# event_id           0   0.000000
# event_name         0   0.000000
# map                0   0.000000
# kills              0   0.000000
# assists            0   0.000000
# deaths             0   0.000000
# ...

# %%
# Replace NULL values with the median value for the flash_assists columnn (using the mean value would result in floats).
df_bo1['flash_assists'].fillna(1, inplace = True)

# %%
# Check to see if there is any pattern in which matches have null values.
#df_bo1.loc[df_bo1['kills_ct'].isnull(), 'match_id']

# %% [markdown]
# Since there doesn't seem to be any reason or rhyme as to which matches have null values, we should not simply drop the rows when creating/modifying the grouped by team dataframe. If we drop the 2862 rows, then when we later need to aggregate over the grouped match_ids and team names, not all aggregations will have 5 player rows to begin with. For this reason we should impute the missing values instead of dropping the rows like we will for the individual performance dataframe.

# %%
# Create a copy of the dataframe so that we can make the grouped by team dataframe using the same structure.
df_bo1_team = df_bo1.copy()

# %%
# Drop the NULL rows in the individual player performance dataframe.
df_bo1.dropna(subset = ['kills_ct'], inplace = True)

# %%
# Take a close look at the remaining rows with NULL values.
df_bo1.loc[df_bo1['adr'].isnull()]
# Out:
#              date player_name              team      opponent        country  \
# 480    2020-02-25      JMaldo          Monstars    Big Frames  United States
# 45647  2019-05-17    Muenster  Party Astronauts  Spacestation  United States
# 171214 2017-10-05   autimatic            Cloud9            SK  United States
# 254360 2016-04-24      dayV1D             KKona        Liquid  United States
#
#         player_id  match_id  event_id                             event_name  \
# 480          5155   2339549      5151       ESEA MDL Season 33 North America
# 45647       16681   2333386      4502       ESEA MDL Season 31 North America
# 171214       8735   2314373      2867  ESL Pro League Season 6 North America
# 254360      11137   2302286      2124                ESL Pro League Season 3
#
#                 map  kills  assists  deaths  hs  flash_assists  kast  kddiff  \
# 480          Mirage      0        0       2   0            0.0  95.2      -2
# ...

# %% [markdown]
# It looks like in these 4 extremely rare cases, both the adr_ct and adr_t values are 0. This would imply that the total adr in these situations were also 0. Since this is such a small subset of our data and because we don't know if this was just simply input incorrectly (adr should have been set to 0 if it was input correctly) we will just drop these 4 rows.

# %%
# Check to see if all NULL values are gone.
df_bo1_missing = pd.concat([df_bo1.isnull().sum(), 100 * df_bo1.isnull().mean()], axis=1)
df_bo1_missing.columns=['count', '%']
df_bo1_missing.sort_values(by= ['count', '%'], ascending = False)
# Out:
#                count         %
# adr                4  0.003065
# date               0  0.000000
# player_name        0  0.000000
# team               0  0.000000
# opponent           0  0.000000
# country            0  0.000000
# player_id          0  0.000000
# match_id           0  0.000000
# event_id           0  0.000000
# event_name         0  0.000000
# map                0  0.000000
# kills              0  0.000000
# assists            0  0.000000
# deaths             0  0.000000
# hs                 0  0.000000
# flash_assists      0  0.000000
# kast               0  0.000000
# kddiff             0  0.000000
# fkdiff             0  0.000000
# rating             0  0.000000
# kills_ct           0  0.000000
# deaths_ct          0  0.000000
# kddiff_ct          0  0.000000
# adr_ct             0  0.000000
# kast_ct            0  0.000000
# rating_ct          0  0.000000
# kills_t            0  0.000000
# deaths_t           0  0.000000
# kddiff_t           0  0.000000
# ...

# %%
df_bo1.dropna(inplace = True)

# %% [markdown]
# There are now no more NULL values in the individual player performance dataframe.

# %%
# Now that all of the NULL values are gone, we can change the data types of columns (as mentioned earlier).
df_bo1['flash_assists'] = df_bo1['flash_assists'].astype('int64')

# %%
df_bo1['kills_ct'] = df_bo1['kills_ct'].astype('int64')

# %%
df_bo1['deaths_ct'] = df_bo1['deaths_ct'].astype('int64')

# %%
df_bo1['kddiff_ct'] = df_bo1['kddiff_ct'].astype('int64')

# %%
df_bo1['kills_t'] = df_bo1['kills_t'].astype('int64')

# %%
df_bo1['deaths_t'] = df_bo1['deaths_t'].astype('int64')

# %%
df_bo1['kddiff_t'] = df_bo1['kddiff_t'].astype('int64')

# %%
# All data types are now correct.
df_bo1.dtypes
# Out:
# date             datetime64[ns]
# player_name              object
# team                     object
# opponent                 object
# country                  object
# player_id                 int64
# match_id                  int64
# event_id                  int64
# event_name               object
# map                      object
# kills                     int64
# assists                   int64
# deaths                    int64
# hs                        int64
# flash_assists             int64
# kast                    float64
# kddiff                    int64
# adr                     float64
# fkdiff                    int64
# rating                  float64
# kills_ct                  int64
# deaths_ct                 int64
# kddiff_ct                 int64
# adr_ct                  float64
# kast_ct                 float64
# rating_ct               float64
# kills_t                   int64
# deaths_t                  int64
# kddiff_t                  int64
# ...

# %%
# Drop the rating columns as they will not be useful in predicting match outcomes later on (rating is determined after a match).
df_bo1 = df_bo1.drop(['rating', 'rating_ct', 'rating_t'], axis = 1)

# %%
# Renaming the final dataframe for individual performance and resetting the index.
df_individual_final = df_bo1.reset_index(drop = True)
df_individual_final.head()
# Out:
#         date player_name           team       opponent        country  \
# 0 2020-02-27    Andersin  Thunder Logic       Station7  United States
# 1 2020-02-27    FrostayK       Station7  Thunder Logic  United States
# 2 2020-02-27   Inseaniac  Thunder Logic       Station7         Canada
# 3 2020-02-27       PureR  Thunder Logic       Station7  United States
# 4 2020-02-27     Sharkie  Thunder Logic       Station7  United States
#
#    player_id  match_id  event_id                        event_name       map  \
# 0      14038   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 1      12090   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 2      18623   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 3      10622   2339816      5151  ESEA MDL Season 33 North America  Overpass
# 4      19476   2339816      5151  ESEA MDL Season 33 North America  Overpass
#
#    kills  assists  deaths  hs  flash_assists  kast  kddiff    adr  fkdiff  \
# ...

# %% [markdown]
# ## Creating the Team Performance Dataframe

# %%
df_bo1_team.head(10)
# Out:
#          date player_name           team       opponent        country  \
# 60 2020-02-27    Andersin  Thunder Logic       Station7  United States
# 61 2020-02-27    FrostayK       Station7  Thunder Logic  United States
# 62 2020-02-27   Inseaniac  Thunder Logic       Station7         Canada
# 63 2020-02-27      JonahP       Station7  Thunder Logic         Canada
# 64 2020-02-27       PureR  Thunder Logic       Station7  United States
# 65 2020-02-27     Sharkie  Thunder Logic       Station7  United States
# 66 2020-02-27      rabbit  Thunder Logic       Station7  United States
# 67 2020-02-27       shonk       Station7  Thunder Logic  United States
# 68 2020-02-27    sterling       Station7  Thunder Logic         Canada
# 69 2020-02-27      zeptic       Station7  Thunder Logic  United States
#
#     player_id  match_id  event_id                        event_name       map  \
# 60      14038   2339816      5151  ESEA MDL Season 33 North America  Overpass
# ...

# %%
# Check to see which columns, if any, have null values and how many there are.
df_bo1_team_missing = pd.concat([df_bo1_team.isnull().sum(), 100 * df_bo1_team.isnull().mean()], axis=1)
df_bo1_team_missing.columns=['count', '%']
df_bo1_team_missing.sort_values(by= ['count', '%'], ascending = False)
# Out:
#                count         %
# kills_ct        2862  2.146006
# deaths_ct       2862  2.146006
# kddiff_ct       2862  2.146006
# adr_ct          2862  2.146006
# kast_ct         2862  2.146006
# rating_ct       2862  2.146006
# kills_t         2862  2.146006
# deaths_t        2862  2.146006
# kddiff_t        2862  2.146006
# adr_t           2862  2.146006
# kast_t          2862  2.146006
# rating_t        2862  2.146006
# adr             1564  1.172730
# kast            1559  1.168981
# date               0  0.000000
# player_name        0  0.000000
# team               0  0.000000
# opponent           0  0.000000
# country            0  0.000000
# player_id          0  0.000000
# match_id           0  0.000000
# event_id           0  0.000000
# event_name         0  0.000000
# map                0  0.000000
# kills              0  0.000000
# assists            0  0.000000
# deaths             0  0.000000
# hs                 0  0.000000
# flash_assists      0  0.000000
# ...

# %%
# View the summary statistics for each column.
df_bo1_team.describe()
# Out:
#            player_id      match_id       event_id         kills  \
# count  133364.000000  1.333640e+05  133364.000000  133364.00000
# mean     9004.208872  2.319425e+06    3398.700489      17.64309
# std      4184.916513  1.048589e+04     789.879418       6.32929
# min         2.000000  2.299001e+06    1615.000000       0.00000
# 25%      7429.000000  2.310948e+06    2729.000000      13.00000
# 50%      9078.000000  2.319395e+06    3374.000000      17.00000
# 75%     11586.000000  2.327738e+06    3965.000000      22.00000
# max     20007.000000  2.339828e+06    5224.000000      75.00000
#
#              assists         deaths             hs  flash_assists  \
# count  133364.000000  133364.000000  133364.000000  133364.000000
# mean        4.109137      17.674132       7.984119       1.010205
# std         2.444149       4.811923       3.879718       1.115998
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
# Drop numerical columns that we do not want to aggregate over (id columns other than match_id).
df_bo1_team.drop(columns = ['player_id', 'event_id'], inplace = True)

# %%
# Check out the NULL value rows.
df_bo1_team[df_bo1_team['kills_ct'].isnull()].head()
# Out:
#           date   player_name      team       opponent      country  match_id  \
# 63  2020-02-27        JonahP  Station7  Thunder Logic       Canada   2339816
# 68  2020-02-27      sterling  Station7  Thunder Logic       Canada   2339816
# 210 2020-02-26          Doom     PC419          ORDER    Australia   2339773
# 212 2020-02-26  Fluent Swede     PC419          ORDER    Australia   2339773
# 214 2020-02-26        Magnum     PC419          ORDER  New Zealand   2339773
#
#                            event_name       map  kills  assists  deaths  hs  \
# 63   ESEA MDL Season 33 North America  Overpass      5        2      18   2
# 68   ESEA MDL Season 33 North America  Overpass      8        4      17   4
# 210      ESEA MDL Season 33 Australia     Dust2      4        1      17   3
# 212      ESEA MDL Season 33 Australia     Dust2      4        0      17   3
# 214      ESEA MDL Season 33 Australia     Dust2      4        1      17   2
#
# ...

# %%
# Ignore this cell --> Old method of dealing with NULL values. We dropped them instead.

# Filling NULL values based on related total columns that have no NULL values.

# The following lines of code use integer division to split a column into values for the related CT and T columns.
#df_bo1_team['kills_ct'] = df_bo1_team['kills_ct'].fillna(df_bo1_team['kills'] // 2)
#df_bo1_team['kills_t'] = df_bo1_team['kills_t'].fillna(df_bo1_team['kills'] // 2)
#df_bo1_team['deaths_ct'] = df_bo1_team['deaths_ct'].fillna(df_bo1_team['deaths'] // 2)
#df_bo1_team['deaths_t'] = df_bo1_team['deaths_t'].fillna(df_bo1_team['deaths'] // 2)
#df_bo1_team['kddiff_ct'] = df_bo1_team['kddiff_ct'].fillna(df_bo1_team['kddiff'] // 2)
#df_bo1_team['kddiff_t'] = df_bo1_team['kddiff_t'].fillna(df_bo1_team['kddiff'] // 2)

# The following lines of code copy the value of a column to the related CT and T columns.
#df_bo1_team['rating_ct'] = df_bo1_team['rating_ct'].fillna(df_bo1_team['rating'])
#df_bo1_team['rating_t'] = df_bo1_team['rating_t'].fillna(df_bo1_team['rating'])
#df_bo1_team['kast_ct'] = df_bo1_team['kast_ct'].fillna(df_bo1_team['kast'])
#df_bo1_team['kast_t'] = df_bo1_team['kast_t'].fillna(df_bo1_team['kast'])
#df_bo1_team['adr_ct'] = df_bo1_team['adr_ct'].fillna(df_bo1_team['adr'])
#df_bo1_team['adr_t'] = df_bo1_team['adr_t'].fillna(df_bo1_team['adr'])

# The following lines of code set the adr to 0 for the 4 rows found earlier to have an adr_ct and adr_t of 0 (we do this because we do not want to impute using the mean for these rows).
#df_bo1_team.loc[(df_bo1_team['adr_t'] == 0) & (df_bo1_team['adr_ct'] == 0), 'adr'] = 0

# The following lines of code copy the average kast and adr (CT and T too), respectively, to rows where all 3 related variables are NULL (i.e. we don't have the total value to copy over).
#df_bo1_team['kast'] = df_bo1_team['kast'].fillna(df_bo1_team['kast'].mean())
#df_bo1_team['kast_ct'] = df_bo1_team['kast_ct'].fillna(df_bo1_team['kast_ct'].mean())
#df_bo1_team['kast_t'] = df_bo1_team['kast_t'].fillna(df_bo1_team['kast_t'].mean())
#df_bo1_team['adr'] = df_bo1_team['adr'].fillna(df_bo1_team['adr'].mean())
#df_bo1_team['adr_ct'] = df_bo1_team['adr_ct'].fillna(df_bo1_team['adr_ct'].mean())
#df_bo1_team['adr_t'] = df_bo1_team['adr_t'].fillna(df_bo1_team['adr_t'].mean())

# %% [markdown]
# We will drop all null values since the rows make up a very small subset of our data (2.15%).

# %%
# Drop all null values
df_bo1_team.dropna(inplace = True)

# %%
df_bo1_team.shape
# Out:
# (130498, 31)

# %%
# Check to see if all NULL values are gone.
df_bo1_team_missing = pd.concat([df_bo1_team.isnull().sum(), 100 * df_bo1_team.isnull().mean()], axis=1)
df_bo1_team_missing.columns=['count', '%']
df_bo1_team_missing.sort_values(by= ['count', '%'], ascending = False)
# Out:
#                count    %
# date               0  0.0
# player_name        0  0.0
# team               0  0.0
# opponent           0  0.0
# country            0  0.0
# match_id           0  0.0
# event_name         0  0.0
# map                0  0.0
# kills              0  0.0
# assists            0  0.0
# deaths             0  0.0
# hs                 0  0.0
# flash_assists      0  0.0
# kast               0  0.0
# kddiff             0  0.0
# adr                0  0.0
# fkdiff             0  0.0
# rating             0  0.0
# kills_ct           0  0.0
# deaths_ct          0  0.0
# kddiff_ct          0  0.0
# adr_ct             0  0.0
# kast_ct            0  0.0
# rating_ct          0  0.0
# kills_t            0  0.0
# deaths_t           0  0.0
# kddiff_t           0  0.0
# adr_t              0  0.0
# kast_t             0  0.0
# rating_t           0  0.0
# match_outcome      0  0.0

# %%
# View the data types before we merge.
df_bo1_team.dtypes
# Out:
# date             datetime64[ns]
# player_name              object
# team                     object
# opponent                 object
# country                  object
# match_id                  int64
# event_name               object
# map                      object
# kills                     int64
# assists                   int64
# deaths                    int64
# hs                        int64
# flash_assists           float64
# kast                    float64
# kddiff                    int64
# adr                     float64
# fkdiff                    int64
# rating                  float64
# kills_ct                float64
# deaths_ct               float64
# kddiff_ct               float64
# adr_ct                  float64
# kast_ct                 float64
# rating_ct               float64
# kills_t                 float64
# deaths_t                float64
# kddiff_t                float64
# adr_t                   float64
# kast_t                  float64
# ...

# %%
# Perform the groupby now that there are no NULL values and therefore we can aggregate over the numerical columns.
df_team_final = df_bo1_team.groupby(['match_id', 'team']).agg({'date':'max', 'opponent':'max', 'event_name':'max', 'map':'max', 'kills':'mean', 'assists':'mean', 'deaths':'mean', 'hs':'mean', 'flash_assists':'mean', 'kast':'mean', 'kddiff':'mean', 'adr':'mean', 'fkdiff':'mean', 'rating':'mean', 'kills_ct':'mean', 'deaths_ct':'mean', 'kddiff_ct':'mean', 'adr_ct':'mean', 'kast_ct':'mean', 'rating_ct':'mean', 'kills_t':'mean', 'deaths_t':'mean', 'kddiff_t':'mean', 'adr_t':'mean', 'kast_t':'mean', 'rating_t':'mean', 'match_outcome':'max',})

# %%
# Drop the rating columns as they will not be useful in predicting match outcomes later on (rating is determined after a match).
df_team_final = df_team_final.drop(['rating', 'rating_ct', 'rating_t'], axis = 1)

# %%
# Make a copy of the dataframe with the indexes reset.
df_team_final_ri = df_team_final.reset_index()

# %%
# View our final dataframe(s).
df_team_final.tail(6)
# Out:
#                              date       opponent  \
# match_id team
# 2339816  Station7      2020-02-27  Thunder Logic
#          Thunder Logic 2020-02-27       Station7
# 2339817  Divine        2020-02-27        Oceanus
#          Oceanus       2020-02-27         Divine
# 2339828  Airborne      2020-02-26         Chiefs
#          Chiefs        2020-02-26       Airborne
#
#                                               event_name       map      kills  \
# match_id team
# 2339816  Station7       ESEA MDL Season 33 North America  Overpass   8.666667
#          Thunder Logic  ESEA MDL Season 33 North America  Overpass  17.000000
# 2339817  Divine         ESEA MDL Season 33 North America     Dust2  20.200000
#          Oceanus        ESEA MDL Season 33 North America     Dust2  17.600000
# 2339828  Airborne           ESEA MDL Season 33 Australia   Inferno  13.200000
#          Chiefs             ESEA MDL Season 33 Australia   Inferno  18.800000
#
# ...

# %%
# View our final dataframe(s).
df_team_final_ri.head()
# Out:
#    match_id           team       date       opponent  \
# 0   2300412  Natus Vincere 2016-01-22             SK
# 1   2300412             SK 2016-01-22  Natus Vincere
# 2   2300413           FaZe 2016-01-22     Luminosity
# 3   2300413     Luminosity 2016-01-22           FaZe
# 4   2300414       Astralis 2016-01-22       Dignitas
#
#                           event_name       map  kills  assists  deaths   hs  \
# 0  DreamHack ZOWIE Open Leipzig 2016    Mirage   15.0      3.2     9.2  5.8
# 1  DreamHack ZOWIE Open Leipzig 2016    Mirage    9.2      2.6    15.0  4.6
# 2  DreamHack ZOWIE Open Leipzig 2016   Inferno   19.8      4.0    14.6  9.0
# 3  DreamHack ZOWIE Open Leipzig 2016   Inferno   14.6      3.6    20.0  5.8
# 4  DreamHack ZOWIE Open Leipzig 2016  Overpass   18.2      2.4    13.0  7.2
#
#    flash_assists   kast  kddiff    adr  fkdiff  kills_ct  deaths_ct  \
# 0            1.0  74.74     5.8  83.26     1.0       3.4        2.2
# ...

# %%
# View the data types post-merge.
df_team_final_ri.dtypes
# Out:
# match_id                  int64
# team                     object
# date             datetime64[ns]
# opponent                 object
# event_name               object
# map                      object
# kills                   float64
# assists                 float64
# deaths                  float64
# hs                      float64
# flash_assists           float64
# kast                    float64
# kddiff                  float64
# adr                     float64
# fkdiff                  float64
# kills_ct                float64
# deaths_ct               float64
# kddiff_ct               float64
# adr_ct                  float64
# kast_ct                 float64
# kills_t                 float64
# deaths_t                float64
# kddiff_t                float64
# adr_t                   float64
# kast_t                  float64
# match_outcome            object
# dtype: object

# %% [markdown]
# ## Saving the Data

# %%
# Save the individual dataframe.
df_individual_final.to_csv('C:/Users/justi/SpringboardDS/Capstone II/1.Match Winner Predictor/df_individual.csv')

# %%
# Save the team dataframe.
df_team_final.to_csv('C:/Users/justi/SpringboardDS/Capstone II/1.Match Winner Predictor/df_team.csv')
