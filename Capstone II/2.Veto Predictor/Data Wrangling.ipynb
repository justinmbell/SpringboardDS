# %% [markdown]
# # Capstone 2: Data Wrangling (Match Winner Predictor)

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### Picks File

# %%
picks_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/picks.xlsx')
picks_df.head()
# Out:
#         date               team_1          team_2  inverted_teams  match_id  \
# 0 2020-03-18              TeamOne         Recon 5               1   2340454
# 1 2020-03-18              Rugratz  Bad News Bears               0   2340453
# 2 2020-03-18  New England Whalers        Station7               0   2340461
# 3 2020-03-17           Complexity           forZe               1   2340279
# 4 2020-03-17          Singularity        Endpoint               0   2340456
#
#    event_id best_of  system t1_removed_1 t1_removed_2 t1_removed_3  \
# 0      5151       3  123412      Vertigo        Train            0
# 1      5151       3  123412        Dust2         Nuke            0
# 2      5243       1  121212       Mirage        Dust2      Vertigo
# 3      5226       3  123412      Inferno         Nuke            0
# 4      5247       3  123412        Train       Mirage            0
#
#   t2_removed_1 t2_removed_2 t2_removed_3 t1_picked_1 t2_picked_1 left_over
# ...

# %%
picks_df.shape
# Out:
# (16035, 17)

# %% [markdown]
# ### Players File

# %%
players_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/players.xlsx')
players_df.head()
# Out:
#         date player_name           team       opponent        country  \
# 0 2020-02-26      Brehze  Evil Geniuses         Liquid  United States
# 1 2020-02-26        CeRq  Evil Geniuses         Liquid       Bulgaria
# 2 2020-02-26       EliGE         Liquid  Evil Geniuses  United States
# 3 2020-02-26       Ethan  Evil Geniuses         Liquid  United States
# 4 2020-02-26         NAF         Liquid  Evil Geniuses         Canada
#
#    player_id  match_id  event_id         event_name  best_of  ...  \
# 0       9136   2339385      4901  IEM Katowice 2020        3  ...
# 1      11219   2339385      4901  IEM Katowice 2020        3  ...
# 2       8738   2339385      4901  IEM Katowice 2020        3  ...
# 3      10671   2339385      4901  IEM Katowice 2020        3  ...
# 4       8520   2339385      4901  IEM Katowice 2020        3  ...
#
#   m3_kddiff_ct m3_adr_ct m3_kast_ct  m3_rating_ct  m3_kills_t  m3_deaths_t  \
# ...

# %%
players_df.shape
# Out:
# (383317, 101)

# %% [markdown]
# ### Results File

# %%
results_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/results.xlsx')
results_df.head()
# Out:
#         date               team_1          team_2     _map  result_1  \
# 0 2020-03-18              Recon 5         TeamOne    Dust2         0
# 1 2020-03-18              Recon 5         TeamOne  Inferno        13
# 2 2020-03-18  New England Whalers        Station7  Inferno        12
# 3 2020-03-18              Rugratz  Bad News Bears  Inferno         7
# 4 2020-03-18              Rugratz  Bad News Bears  Vertigo         8
#
#    result_2  map_winner  starting_ct  ct_1  t_2  t_1  ct_2  event_id  \
# 0        16           2            2     0    1    0    15      5151
# 1        16           2            2     8    6    5    10      5151
# 2        16           2            1     9    6    3    10      5243
# 3        16           2            2     0    8    7     8      5151
# 4        16           2            2     4    5    4    11      5151
#
#    match_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# 0   2340454      62      63           0           2             2
# ...

# %%
results_df.shape
# Out:
# (45773, 19)

# %% [markdown]
# ### Economy File

# %%
#Not sure if I'll need this file, may delete later if not used.
economy_df = pd.read_excel(r'C:/Users/justi/SpringboardDS/Capstone II/data/economy.xlsx')
economy_df.head()
# Out:
#         date  match_id  event_id         team_1         team_2 best_of  \
# 0 2020-03-01   2339402      4901             G2  Natus Vincere       5
# 1 2020-03-01   2339402      4901             G2  Natus Vincere       5
# 2 2020-03-01   2339402      4901             G2  Natus Vincere       5
# 3 2020-02-29   2339401      4901  Natus Vincere       Astralis       3
# 4 2020-02-29   2339401      4901  Natus Vincere       Astralis       3
#
#      _map t1_start t2_start  1_t1  ...  21_winner  22_winner  23_winner  \
# 0    Nuke        t       ct  4350  ...        NaN        NaN        NaN
# 1   Dust2       ct        t  3900  ...        2.0        1.0        1.0
# 2  Mirage        t       ct  4150  ...        NaN        NaN        NaN
# 3   Dust2        t       ct  4150  ...        1.0        NaN        NaN
# 4    Nuke       ct        t  4200  ...        1.0        NaN        NaN
#
#    24_winner  25_winner  26_winner  27_winner  28_winner  29_winner  30_winner
# ...

# %%
economy_df.shape
# Out:
# (43234, 99)

# %% [markdown]
# ## Merging Dataframes

# %%
picks_df.match_id.is_unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7552/1398266311.py in <module>
# ----> 1 picks_df.match_id.is_unique()
#
# TypeError: 'bool' object is not callable

# %%
picks_df['match_id'].dtype

# %%
picks_df.describe

# %%
# We need to get a column of the match_winner names rather than team 1 or 2. Then we can complete the merge.
df = results_df.groupby('match_id').mean().reset_index()
df.head()
# Out:
#    match_id  result_1  result_2  map_winner  starting_ct  ct_1  t_2   t_1  \
# 0   2299001      16.0       4.0         1.0          2.0   4.0  1.0  12.0
# 1   2299003      16.0       9.0         1.0          2.0   4.0  6.0  12.0
# 2   2299011      16.0      12.0         1.0          1.0   7.0  8.0   9.0
# 3   2299040       4.0      16.0         2.0          2.0   1.0  4.0   3.0
# 4   2299042      16.0       6.0         1.0          1.0   9.0  6.0   7.0
#
#    ct_2  event_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# 0   3.0    1934.0     6.0    12.0        16.0         4.0           1.0
# 1   3.0    1934.0     6.0     1.0        16.0         9.0           1.0
# 2   4.0    1934.0    10.0    14.0        16.0        12.0           1.0
# 3  12.0    1934.0    10.0     9.0         4.0        16.0           2.0
# 4   0.0    1934.0    14.0     9.0        16.0         6.0           1.0

# %%
df.loc[df.match_id == 2340454]
# Out:
#        match_id  result_1  result_2  map_winner  starting_ct  ct_1  t_2  t_1  \
# 27241   2340454       6.5      16.0         2.0          2.0   4.0  3.5  2.5
#
#        ct_2  event_id  rank_1  rank_2  map_wins_1  map_wins_2  match_winner
# 27241  12.5    5151.0    62.0    63.0         0.0         2.0           2.0
